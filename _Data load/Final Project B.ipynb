# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen
import json
import folium

# %% [markdown]
# ## Binning courses

# %%
# Reading the dataframe
CD = pd.read_excel("DataFrame.xlsx", dtype={'Course code': str})

# %%
 #Correcting some errors
CD.loc[115,"Course name"] = "Staging co-creation and creativity"
CD.loc[CD["Course name"] == "Facilitating Innovation in Multidisciplinary teams", "Course name"] = "Facilitating Innovation in Multidisciplinary Teams"

# %%
# Adding a column for learning categories
CD[["Category"]] = ""

# %%
CD
# Out:
#     Course code                                        Course name  \
# 0         02266                        User Experience Engineering
# 1         02633    Introduction to programming and data processing
# 2         02266                        User Experience Engineering
# 3         02393                                 Programming in C++
# 4         02450   Introduction to Machine Learning and Data Mining
# ..          ...                                                ...
# 406       42505  Facilitating Innovation in Multidisciplinary T...
# 407       42543                Management of organizational change
# 408       46797  Formula Student Electric: implementation, test...
# 409       63851                                 Project Management
# 410       88383                     Academic Information Retrieval
#
#         Semester Level ECTS    Course type Passed DI students  \
# 0      Fall 2019   MSc    5  Semi-Elective                 14
# 1      Fall 2019   BSc    5       Elective                <=5
# 2      Fall 2020   MSc    5  Semi-Elective                 13
# 3      Fall 2020   MSc    5       Elective                <=5
# 4      Fall 2020   BSc    5       Elective                <=5
# ..           ...   ...  ...            ...                ...
# 406  Spring 2024   MSc    5      Mandatory                 18
# 407  Spring 2024   MSc    5       Elective                 28
# 408  Spring 2024   BSc    5       Elective                <=5
# 409  Spring 2024   MSc    5  Semi-Elective                 13
# 410  Spring 2024   MSc  2,5       Elective                <=5
#
#      Passed students  Average grade Placement  \
# 0              118.0            9.7   January
# 1              220.0            6.2   January
# 2              122.0           10.1   January
# 3              187.0  Pass/Non-Pass      Fall
# 4              550.0            5.5      Fall
# ..               ...            ...       ...
# 406             71.0  Pass/Non-Pass    August
# 407            323.0            8.5    Spring
# 408              6.0  Pass/Non-Pass    Spring
# 409            156.0              9    August
# 410             21.0  Pass/Non-Pass      June
#
#                                     URL  Eval_1.1  Eval_1.2  Eval_1.3  \
# 0    https://kurser.dtu.dk/course/02266       NaN       NaN       NaN
# 1    https://kurser.dtu.dk/course/02633       NaN       NaN       NaN
# 2    https://kurser.dtu.dk/course/02266       4.2       4.7       4.5
# 3    https://kurser.dtu.dk/course/02393       4.0       4.4       4.1
# 4    https://kurser.dtu.dk/course/02450       4.1       4.0       3.5
# ..                                  ...       ...       ...       ...
# 406  https://kurser.dtu.dk/course/42505       3.0       3.4       2.8
# 407  https://kurser.dtu.dk/course/42543       3.0       3.7       2.7
# 408  https://kurser.dtu.dk/course/46797       4.7       4.7       5.0
# 409  https://kurser.dtu.dk/course/63851       4.4       4.4       4.1
# 410  https://kurser.dtu.dk/course/88383       5.0       5.0       5.0
#
#      Eval_1.4  Eval_1.5  Eval_2.1 Category
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         4.6       4.4       3.7
# 3         3.8       4.3       2.9
# 4         3.7       3.7       3.7
# ..        ...       ...       ...      ...
# 406       4.1       3.6       3.2
# 407       3.3       2.9       2.9
# 408       4.7       4.3       4.0
# 409       4.3       4.0       3.7
# 410       5.0       5.0       3.0
#
# [411 rows x 18 columns]

# %%
pd.set_option('display.max_rows', None) #df viewing options

# %%
managementAndBuisness=["42433", '42085', '42383', '42388', '42389', '42421','25352','38106','38113','42009','42196','42107','42438','02431','42415','42105','42543','38301','38001','38302','42016']
medtec=['22435', '27002', '22475','22449','25352','23531','22284']
manufacturingAndMaterials=['41744','41653','41733','10750','28244','41347','11909','31300','41501','41514','41665','41511','42370','10862','41342','41528','41735','46797','12701','41659']
designforpeople=['42071', '22700','42554','02805','42081', "02266"]
supplychain=['41078','42371','02431']
productdesign=['10316', '42071','34052','41742','47203','10750','12250','41078','41618','41031','41342','46797']
systemsengineering=['41078','42083','42371','02431','42370','42270','41061','42543']
circularitySustainability=['28870', '12132', '12139','12104', '25301','47202','12111','12250','30755','22281','42378','42391','12143','12205','12211','12773','12953','23532','27510','38001','12701']
SmartProducts=["02830", '31383', '34338','34540','02162','34367','34723','02564','02160','31375','31392','41028','02105']
tecnicalCompetences=["88383", "02633", "02450", '10316', '27002', '28213','34052','02805','02162','02402','28244','41347','02003','41525','41822','02403','02102','10420','22284','28864','41522','41571','02411','01035','02105','4165','415289','10603','41659']

category_lists = {
    'managementAndBuisness': list(map(str, managementAndBuisness)),
    'medtec': list(map(str, medtec)),
    'manufacturingAndMaterials': list(map(str, manufacturingAndMaterials)),
    'designforpeople': list(map(str, designforpeople)),
    'supplychain': list(map(str, supplychain)),
    'productdesign': list(map(str, productdesign)),
    'systemsengineering': list(map(str, systemsengineering)),
    'circularitySustainability': list(map(str, circularitySustainability)),
    'SmartProducts': list(map(str, SmartProducts)),
    'tecnicalCompetences': list(map(str, tecnicalCompetences)) # Not just programming?
}

def find_categories(course):
    return [name for name, codes in category_lists.items() if course in codes]

CD['Category'] = CD['Course code'].apply(find_categories)
CD['Category'] = CD['Category'].apply(lambda x: ', '.join(x))

# %%
# If a course has the same name as another that already has a category assigned, the same category will be assigned
# Create a mapping from course name to category where Category is not empty
course_to_category = CD[CD["Category"] != ""].drop_duplicates(subset="Course name").set_index("Course name")["Category"]

# Use the mapping to fill missing categories based on course name
CD["Category"] = CD["Category"].replace("", None)  # replace empty string with actual NaN
CD["Category"] = CD["Category"].fillna(CD["Course name"].map(course_to_category))

# %% [markdown]
# #### Til Alex

# %%
# Viser hvilke der mangler ud fra category navn
df_missing_category = CD[CD["Category"].isna()]
df_missing_category_unique = df_missing_category.drop_duplicates(subset="Course name", keep="first").reset_index(drop=True)
df_missing_category_unique
# Out:
#    Course code                                        Course name  \
# 0        02393                                 Programming in C++
# 1        02809                              UX Design Prototyping
# 2        10605                              History of Technology
# 3        31385                           Autonomous robot systems
# 4        34365                                    IoT Prototyping
# 5        41051              Product life and environmental issues
# 6        41073  Development and operation of product/service-s...
# 7        41084                       Biologically Inspired Design
# 8        41628                                  Conceptualisation
# 9        41743   Micro product design, development and production
# 10       42087             Design Methods and Reflective Practice
# 11       42351                       Sustainability in management
# 12       42372      Life Cycle Assessment of Products and Systems
# 13       42387                   Digital Trends for Entrepreneurs
# 14       42390  The role of technology in sustainability trans...
# 15       42430                                 Project Management
# 16       42435                   Knowledge-based Entrepreneurship
# 17       42436                        Technology Entrepreneurship
# 18       42451  Mass Customization - application of product co...
# 19       42452                              Complexity Management
# 20       42575               Technology and Innovation Management
# 21       42577                 Introduction to Business Analytics
# 22       42634                            X-Tech Entrepreneurship
# 23       42879          Decision Support and Strategic Assessment
# 24       02441        Applied Statistics and Statistical Software
# 25       02492   Digital Learning Technology and Entrepreneurship
# 26       11337                                  Agile Prototyping
# 27       12130              Solid Waste Technology and Management
# 28       34366                                Intelligent systems
# 29       42115                               Network Optimization
# 30       42402  Sustainable Operations and Supply Chain Manage...
# 31       42502  Facilitating Innovation in Multidisciplinary T...
# 32       02502                                     Image analysis
# 33       02561                                  Computer Graphics
# 34       12240    Environmental Management, innovation and Ethics
# 35       41612                   Product design and documentation
# 36       41740               Digital Manufacturing - Industry 4.0
# 37       42101                Introduction to Operations Research
# 38       42587  Introduction to Operations and Supply Chain Ma...
# 39       02455                    Experiment in Cognitive Science
# 40       12605  Sustainability and Life Cycle Assessment in th...
# 41       41636                        Design for Circular Economy
# 42       41749                                Precision Machining
# 43       42893                           Psychology for engineers
# 44       46420                     Composite Materials and Fibres
# 45       12105                        Quantitative Sustainability
# 46       38109                                            X-Tech+
# 47       41615                                     Mechanical CAD
# 48       41656    Materials in advanced applications and products
# 49       02170                                   Database Systems
# 50       23552  Development of innovative future food: Ecotrop...
# 51       31070               Hands-on microcontroller programming
# 52       31386                  Building dependable robot systems
# 53       34346  Networking technologies and application develo...
# 54       41072                             Design for interaction
# 55       41083             Technology platforms and architectures
# 56       41635           Robust design of products and mechanisms
# 57       41655                       Advanced surface engineering
# 58       41737                         Design of plastic products
# 59       42090             Holistic Design of Engineering Systems
# 60       42282                                       Smart Cities
# 61       42340            Sustainability in engineering solutions
# 62       42373        Human factors and Implementation management
# 63       42380                             Supply Chain Analytics
# 64       42490  Technology, management, organisation and Busin...
# 65       42576                           From Analytics to Action
# 66       41512  Power transmitting machine elements - design a...
# 67       41739  Experimental plastic and metal processing tech...
# 68       42417                Simulation in Operations Management
# 69       42610                   Theory of Science in Engineering
# 70       02808  Personal Data Interaction for Mobile and Weara...
# 71       34315  Internet of things – application and infrastru...
# 72       34373  Mikrokontroller-programmering til avanceret Io...
# 73       42014               Environmental and Resource Economics
# 74       42386                            Entrepreneurial Finance
# 75       02806             Social data analysis and visualization
#
#        Semester Level ECTS    Course type Passed DI students  Passed students  \
# 0     Fall 2020   MSc    5       Elective                <=5            187.0
# 1     Fall 2020   MSc    5      Mandatory                 22            180.0
# 2     Fall 2020   MSc    5       Elective                <=5             16.0
# 3     Fall 2020   MSc    5       Elective                <=5             95.0
# 4     Fall 2020   MSc    5  Semi-Elective                <=5             20.0
# 5     Fall 2020   BSc    5       Elective                <=5            133.0
# 6     Fall 2020   MSc   10  Semi-Elective                 33             52.0
# 7     Fall 2020   MSc    5  Semi-Elective                 31             58.0
# 8     Fall 2020   MSc   10       Elective                <=5             45.0
# 9     Fall 2020   MSc    5       Elective                <=5             19.0
# 10    Fall 2020   MSc   10       Elective                 32             50.0
# 11    Fall 2020   MSc    5       Elective                  9            230.0
# 12    Fall 2020   MSc   10       Elective                 33            144.0
# 13    Fall 2020   MSc    5       Elective                <=5             29.0
# 14    Fall 2020   MSc    5       Elective                <=5             32.0
# 15    Fall 2020   BSc    5       Elective                  9            512.0
# 16    Fall 2020   MSc    5       Elective                  7            131.0
# 17    Fall 2020   MSc    5       Elective                <=5             67.0
# 18    Fall 2020   MSc   10       Elective                 20             65.0
# 19    Fall 2020   MSc    5       Elective                 30            123.0
# 20    Fall 2020   MSc    5       Elective                 11            204.0
# 21    Fall 2020   MSc    5       Elective                <=5            164.0
# 22    Fall 2020   MSc   10       Elective                <=5            152.0
# 23    Fall 2020   MSc    5       Elective                <=5            124.0
# 24    Fall 2021   MSc    5       Elective                <=5             55.0
# 25    Fall 2021   MSc    5       Elective                <=5             15.0
# 26    Fall 2021   MSc    5       Elective                <=5             51.0
# 27    Fall 2021   MSc   10       Elective                <=5             30.0
# 28    Fall 2021   MSc    5  Semi-Elective                <=5             92.0
# 29    Fall 2021   MSc    5       Elective                <=5            102.0
# 30    Fall 2021   MSc    5       Elective                  6            200.0
# 31    Fall 2021   MSc    5      Mandatory                 20             72.0
# 32    Fall 2022   BSc    5       Elective                <=5            294.0
# 33    Fall 2022   MSc    5       Elective                <=5             59.0
# 34    Fall 2022   MSc    5  Semi-Elective                <=5             93.0
# 35    Fall 2022   BSc   10       Elective                <=5             69.0
# 36    Fall 2022   MSc    5       Elective                <=5             49.0
# 37    Fall 2022   BSc    5       Elective                <=5            142.0
# 38    Fall 2022   BSc    5       Elective                <=5             93.0
# 39    Fall 2023   MSc    5       Elective                <=5             45.0
# 40    Fall 2023   BSc    5       Elective                <=5            161.0
# 41    Fall 2023   MSc    5      Mandatory                 17            189.0
# 42    Fall 2023   MSc    5       Elective                <=5             31.0
# 43    Fall 2023   MSc    5       Elective                  6             93.0
# 44    Fall 2023   MSc    5       Elective                <=5             29.0
# 45    Fall 2024   MSc    5      Mandatory                 19            481.0
# 46    Fall 2024   MSc   10       Elective                <=5             25.0
# 47    Fall 2024   BSc    5       Elective                <=5            126.0
# 48  Spring 2024   MSc   10       Elective                <=5             76.0
# 49  Spring 2020   BSc    5       Elective                <=5            194.0
# 50  Spring 2020   MSc    5       Elective                <=5             27.0
# 51  Spring 2020   MSc    5       Elective                <=5             32.0
# 52  Spring 2020   MSc    5       Elective                <=5             41.0
# 53  Spring 2020   MSc    5       Elective                <=5             19.0
# 54  Spring 2020   MSc    5       Elective                 41             43.0
# 55  Spring 2020   MSc    5  Semi-Elective                 34             68.0
# 56  Spring 2020   MSc    5  Semi-Elective                 30             72.0
# 57  Spring 2020   MSc    5       Elective                <=5             23.0
# 58  Spring 2020   MSc    5       Elective                 19             50.0
# 59  Spring 2020   MSc   10       Elective                 48             61.0
# 60  Spring 2020   MSc    5       Elective                <=5             53.0
# 61  Spring 2020   BSc    5       Elective                <=5             75.0
# 62  Spring 2020   MSc    5       Elective                <=5             38.0
# 63  Spring 2020   MSc    5       Elective                <=5             83.0
# 64  Spring 2020   MSc   10       Elective                <=5            467.0
# 65  Spring 2020   MSc    5       Elective                <=5             91.0
# 66  Spring 2021   MSc    5       Elective                <=5             42.0
# 67  Spring 2021   MSc    5       Elective                <=5             29.0
# 68  Spring 2021   MSc    5       Elective                <=5            152.0
# 69  Spring 2021   BSc    5       Elective                <=5            177.0
# 70  Spring 2022   MSc   10  Semi-Elective                <=5             59.0
# 71  Spring 2022   BSc    5       Elective                <=5             43.0
# 72  Spring 2022   MSc    5       Elective                <=5             14.0
# 73  Spring 2022   MSc    5       Elective                <=5            210.0
# 74  Spring 2022   MSc    5       Elective                  6             82.0
# 75  Spring 2023   MSc    5  Semi-Elective                <=5            146.0
#
#     Average grade Placement                                 URL  Eval_1.1  \
# 0   Pass/Non-Pass      Fall  https://kurser.dtu.dk/course/02393       4.0
# 1             9.5      Fall  https://kurser.dtu.dk/course/02809       3.8
# 2              10      Fall  https://kurser.dtu.dk/course/10605       4.5
# 3   Pass/Non-Pass   January  https://kurser.dtu.dk/course/31385       3.5
# 4   Pass/Non-Pass      Fall  https://kurser.dtu.dk/course/34365       3.8
# 5             8.2      Fall  https://kurser.dtu.dk/course/41051       3.9
# 6             9.3      Fall  https://kurser.dtu.dk/course/41073       4.6
# 7            10.3   January  https://kurser.dtu.dk/course/41084       4.0
# 8             8.3      Fall  https://kurser.dtu.dk/course/41628       3.3
# 9             9.9   January  https://kurser.dtu.dk/course/41743       3.8
# 10            9.7      Fall  https://kurser.dtu.dk/course/42087       4.0
# 11            9.3      Fall  https://kurser.dtu.dk/course/42351       3.4
# 12            8.8      Fall  https://kurser.dtu.dk/course/42372       4.3
# 13           10.2      Fall  https://kurser.dtu.dk/course/42387       3.9
# 14           11.7      Fall  https://kurser.dtu.dk/course/42390       4.2
# 15            8.9   January  https://kurser.dtu.dk/course/42430       4.3
# 16            8.4      Fall  https://kurser.dtu.dk/course/42435       3.3
# 17            9.8      Fall  https://kurser.dtu.dk/course/42436       3.2
# 18            9.5      Fall  https://kurser.dtu.dk/course/42451       4.6
# 19            9.1   January  https://kurser.dtu.dk/course/42452       4.4
# 20            8.9      Fall  https://kurser.dtu.dk/course/42575       3.2
# 21              9      Fall  https://kurser.dtu.dk/course/42577       3.9
# 22            9.3      Fall  https://kurser.dtu.dk/course/42634       3.9
# 23            7.3      Fall  https://kurser.dtu.dk/course/42879       4.2
# 24            7.9   January  https://kurser.dtu.dk/course/02441       4.0
# 25  Pass/Non-Pass      Fall  https://kurser.dtu.dk/course/02492       3.8
# 26  Pass/Non-Pass      Fall  https://kurser.dtu.dk/course/11337       3.0
# 27            8.8      Fall  https://kurser.dtu.dk/course/12130       4.6
# 28            9.9      Fall  https://kurser.dtu.dk/course/34366       3.5
# 29            7.9      Fall  https://kurser.dtu.dk/course/42115       4.6
# 30            6.7      Fall  https://kurser.dtu.dk/course/42402       3.2
# 31  Pass/Non-Pass   January  https://kurser.dtu.dk/course/42502       3.5
# 32            8.8      Fall  https://kurser.dtu.dk/course/02502       4.2
# 33            7.9      Fall  https://kurser.dtu.dk/course/02561       4.6
# 34            7.6   January  https://kurser.dtu.dk/course/12240       4.4
# 35            8.8      Fall  https://kurser.dtu.dk/course/41612       4.5
# 36            9.9      Fall  https://kurser.dtu.dk/course/41740       2.9
# 37            6.4      Fall  https://kurser.dtu.dk/course/42101       4.2
# 38            7.6      Fall  https://kurser.dtu.dk/course/42587       4.5
# 39            9.6      Fall  https://kurser.dtu.dk/course/02455       4.4
# 40            7.4      Fall  https://kurser.dtu.dk/course/12605       3.2
# 41            8.9   January  https://kurser.dtu.dk/course/41636       3.9
# 42            8.3      Fall  https://kurser.dtu.dk/course/41749       4.4
# 43  Pass/Non-Pass      Fall  https://kurser.dtu.dk/course/42893       3.8
# 44            9.6      Fall  https://kurser.dtu.dk/course/46420       4.4
# 45             10      Fall  https://kurser.dtu.dk/course/12105       2.6
# 46  Pass/Non-Pass      Fall  https://kurser.dtu.dk/course/38109       4.4
# 47            8.5      Fall  https://kurser.dtu.dk/course/41615       4.0
# 48            7.4    Spring  https://kurser.dtu.dk/course/41656       3.6
# 49              9    Spring  https://kurser.dtu.dk/course/02170       4.2
# 50  Pass/Non-Pass    Spring  https://kurser.dtu.dk/course/23552       4.2
# 51           10.9      June  https://kurser.dtu.dk/course/31070       3.7
# 52           10.4    Spring  https://kurser.dtu.dk/course/31386       3.1
# 53            9.6    Spring  https://kurser.dtu.dk/course/34346       3.9
# 54             10    Spring  https://kurser.dtu.dk/course/41072       4.0
# 55            9.2    Spring  https://kurser.dtu.dk/course/41083       4.2
# 56            8.7    Spring  https://kurser.dtu.dk/course/41635       4.0
# 57            7.2    Spring  https://kurser.dtu.dk/course/41655       4.3
# 58             11    Spring  https://kurser.dtu.dk/course/41737       3.9
# 59            9.2    Spring  https://kurser.dtu.dk/course/42090       3.7
# 60            8.4      June  https://kurser.dtu.dk/course/42282       2.9
# 61            7.7      June  https://kurser.dtu.dk/course/42340       4.0
# 62            7.9      June  https://kurser.dtu.dk/course/42373       3.4
# 63            9.3    Spring  https://kurser.dtu.dk/course/42380       3.5
# 64            8.4    Spring  https://kurser.dtu.dk/course/42490       3.5
# 65             10    Spring  https://kurser.dtu.dk/course/42576       3.1
# 66            5.4    Spring  https://kurser.dtu.dk/course/41512       4.0
# 67           10.8      June  https://kurser.dtu.dk/course/41739       4.2
# 68            9.2      June  https://kurser.dtu.dk/course/42417       4.3
# 69  Pass/Non-Pass    Spring  https://kurser.dtu.dk/course/42610       3.1
# 70            8.3    Spring  https://kurser.dtu.dk/course/02808       3.1
# 71            6.9    Spring  https://kurser.dtu.dk/course/34315       3.5
# 72  Pass/Non-Pass    Spring  https://kurser.dtu.dk/course/34373       4.4
# 73            6.6    Spring  https://kurser.dtu.dk/course/42014       3.2
# 74            8.4    Spring  https://kurser.dtu.dk/course/42386       3.9
# 75            7.9    Spring  https://kurser.dtu.dk/course/02806       4.4
#
#     Eval_1.2  Eval_1.3  Eval_1.4  Eval_1.5  Eval_2.1 Category
# 0        4.4       4.1       3.8       4.3       2.9      NaN
# 1        4.2       3.7       4.1       3.6       3.7      NaN
# 2        4.8       4.6       4.1       4.4       2.4      NaN
# 3        4.0       3.8       3.3       3.3       3.0      NaN
# 4        4.0       4.0       3.7       3.6       2.9      NaN
# 5        4.0       3.4       3.7       3.2       3.4      NaN
# 6        4.7       4.4       4.3       4.3       3.3      NaN
# 7        4.5       4.0       4.2       3.9       3.0      NaN
# 8        3.9       3.6       4.6       3.6       3.0      NaN
# 9        3.8       3.9       4.5       4.2       4.1      NaN
# 10       4.2       3.8       4.4       3.5       3.2      NaN
# 11       3.9       3.2       4.0       3.4       2.8      NaN
# 12       4.3       3.8       4.0       3.5       4.4      NaN
# 13       4.0       3.4       3.9       3.6       3.7      NaN
# 14       4.3       3.8       3.8       3.2       3.5      NaN
# 15       4.4       4.2       4.5       4.1       3.6      NaN
# 16       4.0       3.6       4.3       3.9       3.0      NaN
# 17       3.8       3.4       3.7       3.8       3.1      NaN
# 18       4.6       4.6       4.4       3.7       3.2      NaN
# 19       4.3       4.0       3.8       3.4       4.1      NaN
# 20       3.8       3.2       3.9       3.8       2.9      NaN
# 21       3.9       3.7       3.4       3.2       3.6      NaN
# 22       4.1       3.8       4.3       3.8       3.6      NaN
# 23       4.3       4.1       3.9       3.6       3.5      NaN
# 24       4.1       3.7       3.6       3.1       4.0      NaN
# 25       3.8       3.0       4.0       3.0       3.5      NaN
# 26       3.6       3.1       4.5       3.2       3.2      NaN
# 27       4.5       4.1       3.5       4.0       3.6      NaN
# 28       3.7       3.6       3.8       4.0       2.9      NaN
# 29       4.6       4.4       3.6       4.4       3.4      NaN
# 30       3.8       2.8       2.4       3.2       2.3      NaN
# 31       4.0       3.7       3.2       3.4       3.0      NaN
# 32       4.4       4.1       2.8       3.9       2.6      NaN
# 33       4.4       4.0       3.3       4.1       3.7      NaN
# 34       4.7       4.4       4.2       4.1       3.3      NaN
# 35       4.4       4.2       4.1       3.7       3.8      NaN
# 36       2.9       2.4       2.1       2.1       3.2      NaN
# 37       4.1       3.6       3.9       4.0       3.3      NaN
# 38       4.6       4.3       4.0       4.3       3.1      NaN
# 39       4.8       4.5       4.9       4.8       3.7      NaN
# 40       3.7       2.9       2.9       2.9       2.9      NaN
# 41       4.2       3.5       3.3       3.1       3.1      NaN
# 42       4.3       3.9       4.4       4.0       3.7      NaN
# 43       4.0       3.5       3.9       3.9       2.6      NaN
# 44       4.5       4.0       4.2       4.2       3.5      NaN
# 45       3.2       2.3       3.1       2.6       2.9      NaN
# 46       4.3       4.2       4.6       3.6       4.0      NaN
# 47       4.2       3.6       2.8       4.2       3.3      NaN
# 48       4.1       3.4       3.4       3.8       3.4      NaN
# 49       4.3       4.0       4.0       4.3       2.8      NaN
# 50       4.4       3.9       4.2       3.9       4.0      NaN
# 51       3.6       3.7       3.0       3.1       3.0      NaN
# 52       3.4       3.7       2.9       3.3       3.1      NaN
# 53       3.2       3.5       3.1       3.1       3.0      NaN
# 54       4.5       4.1       4.6       4.5       3.3      NaN
# 55       4.2       3.8       4.4       3.6       4.1      NaN
# 56       4.1       3.7       4.2       3.4       3.9      NaN
# 57       4.1       3.8       2.5       3.5       3.0      NaN
# 58       4.1       4.0       3.7       4.0       3.1      NaN
# 59       4.4       4.2       4.5       4.1       3.5      NaN
# 60       3.1       2.6       1.3       2.7       2.5      NaN
# 61       4.2       4.2       3.5       3.4       3.0      NaN
# 62       3.3       3.7       4.1       3.2       2.5      NaN
# 63       3.8       3.4       2.6       3.6       3.1      NaN
# 64       3.9       3.4       3.7       3.6       3.0      NaN
# 65       3.7       2.9       3.5       3.4       2.6      NaN
# 66       4.1       3.8       3.1       4.0       3.2      NaN
# 67       3.8       4.4       4.1       3.8       3.5      NaN
# 68       4.6       4.5       4.2       4.1       3.5      NaN
# 69       3.9       3.1       4.4       4.0       2.5      NaN
# 70       3.4       3.2       3.6       3.4       3.6      NaN
# 71       4.3       3.9       3.1       4.3       2.8      NaN
# 72       4.4       4.3       4.0       4.2       3.2      NaN
# 73       3.6       2.8       3.0       3.3       2.7      NaN
# 74       3.9       3.7       3.6       3.2       3.2      NaN
# 75       4.6       4.4       4.4       4.4       3.8      NaN

# %%
# Kan give row index på CD hvis du vil kryds tjekke
name = "Sustainability in management" #Ændrer denne her for at krydstjekke
matching_indices = CD.index[CD["Course name"] == name].tolist()
CD.iloc[matching_indices,:]
# Out:
#    Course code                   Course name   Semester Level ECTS  \
# 22       42351  Sustainability in management  Fall 2020   MSc    5
# 69       42351  Sustainability in management  Fall 2021   MSc    5
# 93       12771  Sustainability in management  Fall 2022   MSc    5
#
#    Course type Passed DI students  Passed students  Average grade Placement  \
# 22    Elective                  9            230.0            9.3      Fall
# 69    Elective                 29            189.0            9.9      Fall
# 93    Elective                 18            193.0  Pass/Non-Pass      Fall
#
#                                    URL  Eval_1.1  Eval_1.2  Eval_1.3  \
# 22  https://kurser.dtu.dk/course/42351       3.4       3.9       3.2
# 69  https://kurser.dtu.dk/course/42351       3.6       4.0       3.4
# 93  https://kurser.dtu.dk/course/12771       3.5       3.9       3.3
#
#     Eval_1.4  Eval_1.5  Eval_2.1 Category
# 22       4.0       3.4       2.8      NaN
# 69       3.8       3.6       2.9      NaN
# 93       4.0       3.8       3.1      NaN

# %% [markdown]
# ## Evaluations

# %%
df_e = CD.copy()

# %%
df_e.dropna(subset=['Eval_1.1', 'Eval_1.2', 'Eval_1.3', 'Eval_1.4', 'Eval_1.5'], inplace=True)

# %%
semester_order = ["Fall 2024", "Spring 2024",
                 "Fall 2023", "Spring 2023",
                 "Fall 2022", "Spring 2022",
                 "Fall 2021", "Spring 2021",
                 "Fall 2020", "Spring 2020"]
semester_order = pd.Categorical(semester_order, categories=semester_order, ordered=True)

# %%
#Sorts out repeating courses by only having the rows of newest passed course
df_e['Semester'] = pd.Categorical(df_e['Semester'], categories=semester_order, ordered=True)
df_e_sorted = df_e.sort_values(by=['Course name', 'Semester'])
df_e = df_e_sorted.drop_duplicates(subset='Course name', keep='first')
df_e = df_e_sorted.drop_duplicates(subset='Course code', keep='first') # sorts out a few errors where the named differed slighly, but the course code is the same

# %%
#consolidating evaluations for those that are not time load related, excluding Eval_2.1
df_e["Evaluation"] = df_e[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5"]].mean(axis=1)
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_16508\3444246911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_e["Evaluation"] = df_e[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5"]].mean(axis=1)

# %%
df_e = df_e.drop(columns = ["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"])

# %%
df_e = df_e.sort_values(by='Evaluation', ascending=True)

# %%
df_e["Evaluation"] = round(df_e["Evaluation"], 2)

# %%
df_e = df_e.reset_index(drop=True)

# %%
from bokeh.models import TapTool, CustomJS, Div
from bokeh.layouts import column
from bokeh.io import output_file, show, save
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, WheelZoomTool
from bokeh.models import Range1d
from bokeh.models import Legend, LegendItem

# %%
# BOKEH

# Create ColumnDataSources
all_source = ColumnDataSource(df_e)
managementAndBuisness_source = ColumnDataSource(df_e[df_e['Category'].str.contains('managementAndBuisness', na=False)])
medtec_source = ColumnDataSource(df_e[df_e['Category'].str.contains('medtec', na=False)])
manufacturingAndMaterials_source = ColumnDataSource(df_e[df_e['Category'].str.contains('manufacturingAndMaterials', na=False)])
designforpeople_source = ColumnDataSource(df_e[df_e['Category'].str.contains('designforpeople', na=False)])
supplychain_source = ColumnDataSource(df_e[df_e['Category'].str.contains('supplychain', na=False)])
productdesign_source = ColumnDataSource(df_e[df_e['Category'].str.contains('productdesign', na=False)])
systemsengineering_source = ColumnDataSource(df_e[df_e['Category'].str.contains('systemsengineering', na=False)])
circularitySustainability_source = ColumnDataSource(df_e[df_e['Category'].str.contains('circularitySustainability', na=False)])
SmartProducts_source = ColumnDataSource(df_e[df_e['Category'].str.contains('SmartProducts', na=False)])
tecnicalCompetences_source = ColumnDataSource(df_e[df_e['Category'].str.contains('tecnicalCompetences', na=False)])

# Create a figure with custom axes labels
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=df_e["Course code"].unique().tolist(),
          width=1000,
          height =600)

# Create individual scatterplots
p.scatter(x="Course code", y='Evaluation', source=managementAndBuisness_source, legend_label="Management and Business",
          size=8, color="blue", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=medtec_source, legend_label="Medtech",
          size=8, color="green", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=manufacturingAndMaterials_source, legend_label="Manufacturing and Materials",
          size=8, color="red", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=designforpeople_source, legend_label="Design for People",
          size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=supplychain_source, legend_label="Supply Chain",
          size=8, color="orange", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=productdesign_source, legend_label="Product Design",
          size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=systemsengineering_source, legend_label="Systems Engineering",
          size=8, color="cyan", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=circularitySustainability_source, legend_label="Circularity and Sustainability",
          size=8, color="pink", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=SmartProducts_source, legend_label="Smart Products",
          size=8, color="brown", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=tecnicalCompetences_source, legend_label="Technical Competences",
          size=8, color="gray", alpha=0.6, marker="circle")

layout = column(p)

#Preactivate wheel zoom
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Plot style
p.xaxis.visible = True
p.legend.title = 'Learning categories'
p.legend.location = 'bottom_right'
p.legend.visible = True
p.legend.click_policy = 'hide'  # Clicking a legend item hides the corresponding data
p.xaxis.major_label_orientation = -0.785
#p.legend.spacing = 4

# Finalization
output_file("Evaluation_plot.html")
show(layout)
save(p)
# Out:
# 'C:\\Users\\johan\\Final Project\\_Data load\\Evaluation_plot.html'

# %% [markdown]
# ## Tap tool (fucking around)
# Implement more stuff to show when you click
# Assign legends as in assignment 2

# %%
#WORKS
from bokeh.models import ColumnDataSource, Range1d, WheelZoomTool, Div, CustomJS
from bokeh.plotting import figure, show, output_file, save
from bokeh.layouts import column
import pandas as pd

# Create ColumnDataSources
all_source = ColumnDataSource(df_e.sort_values(by=["Evaluation"]))
#managementAndBuisness_source = ColumnDataSource(df_e[df_e['Category'].str.contains('managementAndBuisness', na=False)])
#medtec_source = ColumnDataSource(df_e[df_e['Category'].str.contains('medtec', na=False)])
#manufacturingAndMaterials_source = ColumnDataSource(df_e[df_e['Category'].str.contains('manufacturingAndMaterials', na=False)])
#designforpeople_source = ColumnDataSource(df_e[df_e['Category'].str.contains('designforpeople', na=False)])
#supplychain_source = ColumnDataSource(df_e[df_e['Category'].str.contains('supplychain', na=False)])
#productdesign_source = ColumnDataSource(df_e[df_e['Category'].str.contains('productdesign', na=False)])
#systemsengineering_source = ColumnDataSource(df_e[df_e['Category'].str.contains('systemsengineering', na=False)])
#circularitySustainability_source = ColumnDataSource(df_e[df_e['Category'].str.contains('circularitySustainability', na=False)])
#SmartProducts_source = ColumnDataSource(df_e[df_e['Category'].str.contains('SmartProducts', na=False)])
#tecnicalCompetences_source = ColumnDataSource(df_e[df_e['Category'].str.contains('tecnicalCompetences', na=False)])

# Create figure
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=sorted(df_e["Course code"].unique().tolist()),
           width=1000,
           height=600,
           tools="tap")

# Scatter plots for each category
#p.scatter(x="Course code", y='Evaluation', source=managementAndBuisness_source, legend_label="Management and Business", size=8, color="blue", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=medtec_source, legend_label="Medtech", size=8, color="green", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=manufacturingAndMaterials_source, legend_label="Manufacturing and Materials", size=8, color="red", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=designforpeople_source, legend_label="Design for People",size=8, color="purple", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=supplychain_source, legend_label="Supply Chain",size=8, color="orange", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=productdesign_source, legend_label="Product Design",size=8, color="purple", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=systemsengineering_source, legend_label="Systems Engineering",size=8, color="cyan", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=circularitySustainability_source, legend_label="Circularity and Sustainability",size=8, color="pink", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=SmartProducts_source, legend_label="Smart Products",size=8, color="brown", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=tecnicalCompetences_source, legend_label="Technical Competences",size=8, color="gray", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=all_source, legend_label="All",size=8, color="gray", alpha=0.6, marker="circle")
# Styling
p.legend.title = 'Learning categories'
p.legend.location = 'bottom_right'
p.legend.visible = True
p.legend.click_policy = 'hide'
p.xaxis.major_label_orientation = -0.785
p.xaxis.visible = True

# Zoom tool setup
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Div to display course info
div = Div(text="Click on a course dot to see details", width=800)

# JS callback on full source
callback = CustomJS(args=dict(source=all_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")
all_source.selected.js_on_change('indices', callback)

# Final layout and display
layout = column(p, div)

output_file("Evaluation_plot.html")
show(layout)

# %%
#FUCKING AROUND

# %%
unique_categories_string = ", ".join(df_e['Category'].unique().astype(str))

# %%
#WORKS
from bokeh.models import ColumnDataSource, Range1d, WheelZoomTool, Div, CustomJS
from bokeh.plotting import figure, show, output_file, save
from bokeh.layouts import column
import pandas as pd

# Create ColumnDataSources
#all_source = ColumnDataSource(df_e.sort_values(by=["Evaluation"]))
managementAndBuisness_source = ColumnDataSource(df_e[df_e['Category'].str.contains('managementAndBuisness', na=False)])
medtec_source = ColumnDataSource(df_e[df_e['Category'].str.contains('medtec', na=False)])
manufacturingAndMaterials_source = ColumnDataSource(df_e[df_e['Category'].str.contains('manufacturingAndMaterials', na=False)])
designforpeople_source = ColumnDataSource(df_e[df_e['Category'].str.contains('designforpeople', na=False)])
supplychain_source = ColumnDataSource(df_e[df_e['Category'].str.contains('supplychain', na=False)])
productdesign_source = ColumnDataSource(df_e[df_e['Category'].str.contains('productdesign', na=False)])
systemsengineering_source = ColumnDataSource(df_e[df_e['Category'].str.contains('systemsengineering', na=False)])
circularitySustainability_source = ColumnDataSource(df_e[df_e['Category'].str.contains('circularitySustainability', na=False)])
SmartProducts_source = ColumnDataSource(df_e[df_e['Category'].str.contains('SmartProducts', na=False)])
tecnicalCompetences_source = ColumnDataSource(df_e[df_e['Category'].str.contains('tecnicalCompetences', na=False)])

# Create figure
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=sorted(df_e["Course code"].unique().tolist()),
           width=1000,
           height=600,
           tools="tap")

# Scatter plots for each category
#p.scatter(x='Course code', y='Evaluation', source=all_source, legend_label="All",size=8, color="gray", alpha=0.6, marker="circle")
p.scatter(x="Course code", y='Evaluation', source=managementAndBuisness_source, legend_label="Management and Business", size=8, color="blue", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=medtec_source, legend_label="Medtech", size=8, color="green", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=manufacturingAndMaterials_source, legend_label="Manufacturing and Materials", size=8, color="red", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=designforpeople_source, legend_label="Design for People",size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=supplychain_source, legend_label="Supply Chain",size=8, color="orange", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=productdesign_source, legend_label="Product Design",size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=systemsengineering_source, legend_label="Systems Engineering",size=8, color="cyan", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=circularitySustainability_source, legend_label="Circularity and Sustainability",size=8, color="pink", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=SmartProducts_source, legend_label="Smart Products",size=8, color="brown", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=tecnicalCompetences_source, legend_label="Technical Competences",size=8, color="gray", alpha=0.6, marker="circle")


# Styling
p.legend.title = 'Learning categories'
p.legend.location = 'bottom_right'
p.legend.visible = True
p.legend.click_policy = 'mute'
p.xaxis.major_label_orientation = -0.785
p.xaxis.visible = True

# Zoom tool setup
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Div to display course info
div = Div(text="Click on a course dot to see details", width=800)

# Callbacks
callback1 = CustomJS(args=dict(source=managementAndBuisness_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")

callback2 = CustomJS(args=dict(source=medtec_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")

managementAndBuisness_source.selected.js_on_change('indices', callback1)
medtec_source.selected.js_on_change('indices', callback2)

# Final layout and display
layout = column(p, div)

output_file("Evaluation_plot.html")
show(layout)

# %%
#WORKS
from bokeh.models import ColumnDataSource, Range1d, WheelZoomTool, Div, CustomJS
from bokeh.plotting import figure, show, output_file, save
from bokeh.layouts import column
import pandas as pd

# Create ColumnDataSources
all_source = ColumnDataSource(df_e.sort_values(by=["Evaluation"]))

# Create figure
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=sorted(df_e["Course code"].unique().tolist()),
           width=1000,
           height=600,
           tools="tap")

# Scatter plots for each category
p.scatter(x='Course code', y='Evaluation', source=all_source, legend_label="All",size=8, color="red", alpha=0.6, marker="circle")


# Adjust title font size and style
p.title.text_font_size = "20pt"  # Increase title font size
p.title.text_font_style = "bold"  # Make title bold
p.title.text_font = "Arial"  # Change title font (optional)

# Adjust axis labels font size and style
p.xaxis.axis_label_text_font_size = "14pt"  # X-axis label size
p.yaxis.axis_label_text_font_size = "14pt"  # Y-axis label size
p.xaxis.axis_label_text_font_style = "normal"  # X-axis label style
p.yaxis.axis_label_text_font_style = "normal"  # Y-axis label style
p.xaxis.axis_label_text_font = "Arial"  # X-axis label font (optional)
p.yaxis.axis_label_text_font = "Arial"  # Y-axis label font (optional)

# Adjust tick labels font size
p.xaxis.major_label_text_font_size = "12pt"  # X-axis tick labels
p.yaxis.major_label_text_font_size = "12pt"  # Y-axis tick labels



# Legend
#p.legend.title = 'Learning categories'
#p.legend.location = 'bottom_right'
#p.legend.visible = True
#p.legend.click_policy = 'mute'
#p.xaxis.major_label_orientation = -0.785
#p.xaxis.visible = True

# Zoom tool setup
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Div to display course info
div = Div(text="Click on a course dot to see details", width=800)

# Callbacks
callback = CustomJS(args=dict(source=all_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")

all_source.selected.js_on_change('indices', callback)

# Final layout and display
layout = column(p, div)

output_file("Evaluation_plot.html")
show(layout)
