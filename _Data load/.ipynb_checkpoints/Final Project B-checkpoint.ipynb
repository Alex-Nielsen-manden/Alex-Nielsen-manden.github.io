# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen
import json
import folium
import seaborn as sns

# %% [markdown]
# ## Binning courses

# %%
# Reading the dataframe
CD = pd.read_excel("DataFrame.xlsx", dtype={'Course code': str})

# %%
 #Correcting some errors
CD.loc[115,"Course name"] = "Staging co-creation and creativity"
CD.loc[CD["Course name"] == "Facilitating Innovation in Multidisciplinary teams", "Course name"] = "Facilitating Innovation in Multidisciplinary Teams"

# %%
# Adding a column for learning categories
CD[["Category"]] = ""

# %%
CD
# Out:
#     Course code                                        Course name  \
# 0         02266                        User Experience Engineering
# 1         02633    Introduction to programming and data processing
# 2         02266                        User Experience Engineering
# 3         02393                                 Programming in C++
# 4         02450   Introduction to Machine Learning and Data Mining
# 5         02809                              UX Design Prototyping
# 6         10316  Materials design with machine learning and art...
# 7         10605                              History of Technology
# 8         22435                     Biomedical product development
# 9         27002                                       Life Science
# 10        28870                          Energy and Sustainability
# 11        31385                           Autonomous robot systems
# 12        34365                                    IoT Prototyping
# 13        41051              Product life and environmental issues
# 14        41073  Development and operation of product/service-s...
# 15        41084                       Biologically Inspired Design
# 16        41628                                  Conceptualisation
# 17        41743   Micro product design, development and production
# 18        42071  Design and development in an organizational co...
# 19        42081                 Staging co-creation and creativity
# 20        42085                        Strategy, design and market
# 21        42087             Design Methods and Reflective Practice
# 22        42351                       Sustainability in management
# 23        42372      Life Cycle Assessment of Products and Systems
# 24        42383                        Entrepreneurial Life Skills
# 25        42387                   Digital Trends for Entrepreneurs
# 26        42388                      Due Diligence of New Ventures
# 27        42389                                Feasibility Studies
# 28        42390  The role of technology in sustainability trans...
# 29        42430                                 Project Management
# 30        42435                   Knowledge-based Entrepreneurship
# 31        42436                        Technology Entrepreneurship
# 32        42451  Mass Customization - application of product co...
# 33        42452                              Complexity Management
# 34        42575               Technology and Innovation Management
# 35        42577                 Introduction to Business Analytics
# 36        42634                            X-Tech Entrepreneurship
# 37        42879          Decision Support and Strategic Assessment
# 38        88383                     Academic Information Retrieval
# 39        02266                        User Experience Engineering
# 40        02441        Applied Statistics and Statistical Software
# 41        02492   Digital Learning Technology and Entrepreneurship
# 42        02631    Introduction to programming and data processing
# 43        02633    Introduction to programming and data processing
# 44        02809                              UX Design Prototyping
# 45        02830      Advanced Project in Digital Media Engineering
# 46        11337                                  Agile Prototyping
# 47        12130              Solid Waste Technology and Management
# 48        12132          LCA Modelling of Waste Management Systems
# 49        12139                               Resource Engineering
# 50        22700                    Effective Science Communication
# 51        28213                                 Polymer Technology
# 52        31383                                           Robotics
# 53        31385                           Autonomous robot systems
# 54        34052                                   Nonlinear optics
# 55        34338  Telecommunication programming projects with Ar...
# 56        34365                                    IoT Prototyping
# 57        34366                                Intelligent systems
# 58        34540  Light emitting diodes and photovoltaics for en...
# 59        41073  Development and operation of product/service-s...
# 60        41084                       Biologically Inspired Design
# 61        41628                                  Conceptualisation
# 62        41742  Introduction to micro mechanical systems desig...
# 63        41743   Micro product design, development and production
# 64        41744                            Precision manufacturing
# 65        42081                 Staging co-creation and creativity
# 66        42085                 Business Design for Sustainability
# 67        42087             Design Methods and Reflective Practice
# 68        42115                               Network Optimization
# 69        42351                       Sustainability in management
# 70        42372      Life Cycle Assessment of Products and Systems
# 71        42390  The role of technology in sustainability trans...
# 72        42402  Sustainable Operations and Supply Chain Manage...
# 73        42430                                 Project Management
# 74        42435                   Knowledge-based Entrepreneurship
# 75        42436                        Technology Entrepreneurship
# 76        42451  Mass Customization - application of product co...
# 77        42502  Facilitating Innovation in Multidisciplinary T...
# 78        42554       Social Entrepreneurship: Theory and Practice
# 79        42575               Technology and Innovation Management
# 80        42634                            X-Tech Entrepreneurship
# 81        42879          Decision Support and Strategic Assessment
# 82        47203                       Design-Build 3: solar cooker
# 83        02266                        User Experience Engineering
# 84        02450   Introduction to Machine Learning and Data Mining
# 85        02492   Digital Learning Technology and Entrepreneurship
# 86        02502                                     Image analysis
# 87        02561                                  Computer Graphics
# 88        02805                     Social graphs and interactions
# 89        02809                              UX Design Prototyping
# 90        02830      Advanced Project in Digital Media Engineering
# 91        12104                            Environmental Modelling
# 92        12240    Environmental Management, innovation and Ethics
# 93        12771                       Sustainability in management
# 94        12772      Life Cycle Assessment of Products and Systems
# 95        22475               Tissue and movement biomechanics DTU
# 96        25301  Introduction to aquatic ecosystems, anthropoge...
# 97        34365                                    IoT Prototyping
# 98        38101                   Knowledge-based Entrepreneurship
# 99        38103                            X-Tech Entrepreneurship
# 100       38105                   Digital Trends for Entrepreneurs
# 101       38107                 Business Design for Sustainability
# 102       38108               Technology and Innovation Management
# 103       41051              Product life and environmental issues
# 104       41073  Development and operation of product/service-s...
# 105       41084                       Biologically Inspired Design
# 106       41612                   Product design and documentation
# 107       41628                                  Conceptualisation
# 108       41637  Mass Customization - application of product co...
# 109       41638                              Complexity Management
# 110       41653                                          Corrosion
# 111       41733  Metallurgy, design and manufacturing of cast c...
# 112       41740               Digital Manufacturing - Industry 4.0
# 113       41743   Micro product design, development and production
# 114       41938                                  Agile Prototyping
# 115       42081                 Staging co-creation and creativity
# 116       42087             Design Methods and Reflective Practice
# 117       42101                Introduction to Operations Research
# 118       42115                               Network Optimization
# 119       42402  Sustainable Operations and Supply Chain Manage...
# 120       42421                        Management and Organization
# 121       42430                                 Project Management
# 122       42502  Facilitating Innovation in Multidisciplinary T...
# 123       42587  Introduction to Operations and Supply Chain Ma...
# 124       02162                             Software Engineering 2
# 125       02266                        User Experience Engineering
# 126       02402                                         Statistics
# 127       02441        Applied Statistics and Statistical Software
# 128       02455                    Experiment in Cognitive Science
# 129       02492   Digital Learning Technology and Entrepreneurship
# 130       02561                                  Computer Graphics
# 131       02809                              UX Design Prototyping
# 132       02830      Advanced Project in Digital Media Engineering
# 133       10605                              History of Technology
# 134       10610                              History of Technology
# 135       10750      Innovation Projects at the Physics Department
# 136       12240    Environmental Management, innovation and Ethics
# 137       12605  Sustainability and Life Cycle Assessment in th...
# 138       12772      Life Cycle Assessment of Products and Systems
# 139       28244          Combustion and High Temperature Processes
# 140       34365                                    IoT Prototyping
# 141       34366                                Intelligent systems
# 142       38102                        Technology Entrepreneurship
# 143       38103                            X-Tech Entrepreneurship
# 221       02450   Introduction to Machine Learning and Data Mining
# 222       02564                                 Real-Time Graphics
# 223       02633    Introduction to programming and data processing
# 224       10603  How Did Edison and Bohr Know - and How do You?...
# 225       11909                        Building Design Project 1:1
# 226       23531       Entrepreneurship in food and bio engineering
# 227       23552  Development of innovative future food: Ecotrop...
# 228       31070               Hands-on microcontroller programming
# 229       31300                            Linear control design 1
# 230       31386                  Building dependable robot systems
# 231       34346  Networking technologies and application develo...
# 232       41072                             Design for interaction
# 233       41078                                Industrial design 2
# 234       41083             Technology platforms and architectures
# 235       41501                            Strength of materials 1
# 236       41514                              Dynamics of machinery
# 237       41618                           CAD for design engineers
# 238       41635           Robust design of products and mechanisms
# 239       41655                       Advanced surface engineering
# 240       41656    Materials in advanced applications and products
# 241       41665  Physical metallurgy: deformation and rekrystal...
# 242       41737                         Design of plastic products
# 243       42083                    Service and Work Systems Design
# 244       42090             Holistic Design of Engineering Systems
# 245       42107                     Decision Support for Engineers
# 246       42196                            The economics of cities
# 247       42282                                       Smart Cities
# 248       42340            Sustainability in engineering solutions
# 249       42371      Design of Lean Production and Service Systems
# 250       42373        Human factors and Implementation management
# 251       42380                             Supply Chain Analytics
# 252       42429                                 Project Management
# 253       42433  Advanced Engineering Project, Program and Port...
# 254       42438  Business model design for growth entrepreneurship
# 255       42490  Technology, management, organisation and Busin...
# 256       42576                           From Analytics to Action
# 257       42634                            X-Tech Entrepreneurship
# 258       02102                           Introductory Programming
# 259       02160         Agile Object-oriented Software Development
# 260       02393                                 Programming in C++
# 261       02431                                    Risk Management
# 262       02450   Introduction to Machine Learning and Data Mining
# 263       02631    Introduction to programming and data processing
# 264       10420                                  Physics of Sports
# 265       10603  Creation and Circulation of Knowledge. How Did...
# 266       22281                                       Biomaterials
# 267       22284                    Body barrier and organ modeling
# 268       23552  Development of innovative future food: Ecotrop...
# 269       28864                 Introduction to Matlab programming
# 270       31386                  Building dependable robot systems
# 271       34346  Networking technologies and application develo...
# 272       41072                             Design for interaction
# 273       41083             Technology platforms and architectures
# 274       41511                          Machine elements - basics
# 275       41512  Power transmitting machine elements - design a...
# 276       41522                   Advanced dynamics and vibrations
# 277       41571                            Strength of Materials 1
# 278       41615                                     Mechanical CAD
# 279       41635           Robust design of products and mechanisms
# 280       41656    Materials in advanced applications and products
# 281       41669                       Advanced surface engineering
# 282       41737                         Design of plastic products
# 283       41739  Experimental plastic and metal processing tech...
# 284       42090             Holistic Design of Engineering Systems
# 285       42270                     Introduction to Urban Planning
# 286       42282                                       Smart Cities
# 287       42340            Sustainability in engineering solutions
# 288       42370              Design of Production Logistic Systems
# 289       42373        Human factors and Implementation management
# 290       42415                                Engineering Economy
# 291       42417                Simulation in Operations Management
# 292       42429                                 Project Management
# 293       42433  Advanced Engineering Project, Program and Port...
# 294       42490  Technology, management, organisation and Busin...
# 295       42505  Facilitating Innovation in Multidisciplinary T...
# 296       42576                           From Analytics to Action
# 297       42610                   Theory of Science in Engineering
# 298       42634                            X-Tech Entrepreneurship
# 299       88383                     Academic Information Retrieval
# 300       02170                                   Database Systems
# 374       46760               Hands-on microcontroller programming
# 375       02450   Introduction to Machine Learning and Data Mining
# 376       02502                                     Image analysis
# 377       02806             Social data analysis and visualization
# 378       02808  Personal Data Interaction for Mobile and Weara...
# 379       10603  Creation and Circulation of Knowledge. How Did...
# 380       10862                          Polymer micro fabrication
# 381       12211  Environmental solutions in water, sanitation, ...
# 382       12773             Advanced life cycle assessment methods
# 383       12953  Absolute environmental sustainability assessme...
# 384       23532              Beer brewing and safe food production
# 385       27510                         Biosensors and bioanalysis
# 386       34315  Internet of things – application and infrastru...
# 387       34755                  Building dependable robot systems
# 388       38001                       Sustainable Entrepreneurship
# 389       38103                            X-Tech Entrepreneurship
# 390       38104                            Entrepreneurial Finance
# 391       38106  Developing an Entrepreneurial mindset through ...
# 392       38109                                            X-Tech+
# 393       38302                      Module 2: Start-up Incubation
# 394       41083             Technology platforms and architectures
# 395       41342                                             Ecocar
# 396       41528                    Advanced mechanics of materials
# 397       41615                                     Mechanical CAD
# 398       41635           Robust design of products and mechanisms
# 399       41639             Holistic Design of Engineering Systems
# 400       41735                Experimental methods in 3D printing
# 401       41737                         Design of plastic products
# 402       41739  Experimental plastic and metal processing tech...
# 403       42016                     Business Economics and Finance
# 404       42101                Introduction to Operations Research
# 405       42503  Facilitating Innovation in Multidisciplinary T...
# 406       42505  Facilitating Innovation in Multidisciplinary T...
# 407       42543                Management of organizational change
# 408       46797  Formula Student Electric: implementation, test...
# 409       63851                                 Project Management
# 410       88383                     Academic Information Retrieval
#
#         Semester                                  Level ECTS    Course type  \
# 0      Fall 2019                                    MSc    5  Semi-Elective
# 1      Fall 2019                                    BSc    5       Elective
# 2      Fall 2020                                    MSc    5  Semi-Elective
# 3      Fall 2020                                    MSc    5       Elective
# 4      Fall 2020                                    BSc    5       Elective
# 5      Fall 2020                                    MSc    5      Mandatory
# 6      Fall 2020                                    MSc    5       Elective
# 7      Fall 2020                                    MSc    5       Elective
# 8      Fall 2020                                    MSc   10       Elective
# 9      Fall 2020                                    BSc    5       Elective
# 10     Fall 2020                                    MSc    5       Elective
# 11     Fall 2020                                    MSc    5       Elective
# 12     Fall 2020                                    MSc    5  Semi-Elective
# 13     Fall 2020                                    BSc    5       Elective
# 14     Fall 2020                                    MSc   10  Semi-Elective
# 15     Fall 2020                                    MSc    5  Semi-Elective
# 16     Fall 2020                                    MSc   10       Elective
# 17     Fall 2020                                    MSc    5       Elective
# 18     Fall 2020                                    MSc    5       Elective
# 19     Fall 2020                                    MSc    5       Elective
# 20     Fall 2020                                    MSc    5       Elective
# 21     Fall 2020                                    MSc   10       Elective
# 22     Fall 2020                                    MSc    5       Elective
# 23     Fall 2020                                    MSc   10       Elective
# 24     Fall 2020                                    MSc    5       Elective
# 25     Fall 2020                                    MSc    5       Elective
# 26     Fall 2020                                    MSc    5       Elective
# 27     Fall 2020                                    MSc   10       Elective
# 28     Fall 2020                                    MSc    5       Elective
# 29     Fall 2020                                    BSc    5       Elective
# 30     Fall 2020                                    MSc    5       Elective
# 31     Fall 2020                                    MSc    5       Elective
# 32     Fall 2020                                    MSc   10       Elective
# 33     Fall 2020                                    MSc    5       Elective
# 34     Fall 2020                                    MSc    5       Elective
# 35     Fall 2020                                    MSc    5       Elective
# 36     Fall 2020                                    MSc   10       Elective
# 37     Fall 2020                                    MSc    5       Elective
# 38     Fall 2020                                    MSc  2,5       Elective
# 39     Fall 2021                                    MSc    5  Semi-Elective
# 40     Fall 2021                                    MSc    5       Elective
# 41     Fall 2021                                    MSc    5       Elective
# 42     Fall 2021                                    BSc    5       Elective
# 43     Fall 2021                                    BSc    5       Elective
# 44     Fall 2021                                    MSc    5      Mandatory
# 45     Fall 2021                                    MSc   10  Semi-Elective
# 46     Fall 2021                                    MSc    5       Elective
# 47     Fall 2021                                    MSc   10       Elective
# 48     Fall 2021                                    MSc    5       Elective
# 49     Fall 2021                                    BSc    5       Elective
# 50     Fall 2021                                    MSc    5       Elective
# 51     Fall 2021                                    MSc    5       Elective
# 52     Fall 2021                                    MSc    5       Elective
# 53     Fall 2021                                    MSc    5       Elective
# 54     Fall 2021                                    MSc   10       Elective
# 55     Fall 2021                                    BSc    5       Elective
# 56     Fall 2021                                    MSc    5  Semi-Elective
# 57     Fall 2021                                    MSc    5  Semi-Elective
# 58     Fall 2021                                    MSc    5       Elective
# 59     Fall 2021                                    MSc   10  Semi-Elective
# 60     Fall 2021                                    MSc    5  Semi-Elective
# 61     Fall 2021                                    MSc   10       Elective
# 62     Fall 2021                                    MSc    5       Elective
# 63     Fall 2021                                    MSc    5       Elective
# 64     Fall 2021                                    MSc    5       Elective
# 65     Fall 2021                                    MSc    5       Elective
# 66     Fall 2021                                    MSc    5       Elective
# 67     Fall 2021                                    MSc   10       Elective
# 68     Fall 2021                                    MSc    5       Elective
# 69     Fall 2021                                    MSc    5       Elective
# 70     Fall 2021                                    MSc   10       Elective
# 71     Fall 2021                                    MSc    5       Elective
# 72     Fall 2021                                    MSc    5       Elective
# 73     Fall 2021                                    BSc    5       Elective
# 74     Fall 2021                                    MSc    5       Elective
# 75     Fall 2021                                    MSc    5       Elective
# 76     Fall 2021                                    MSc   10       Elective
# 77     Fall 2021                                    MSc    5      Mandatory
# 78     Fall 2021                                    MSc    5       Elective
# 79     Fall 2021                                    MSc    5       Elective
# 80     Fall 2021                                    MSc   10       Elective
# 81     Fall 2021                                    MSc    5       Elective
# 82     Fall 2021                                    BSc    5       Elective
# 83     Fall 2022                                    MSc    5  Semi-Elective
# 84     Fall 2022                                    BSc    5       Elective
# 85     Fall 2022                                    MSc    5       Elective
# 86     Fall 2022                                    BSc    5       Elective
# 87     Fall 2022                                    MSc    5       Elective
# 88     Fall 2022                                    MSc   10       Elective
# 89     Fall 2022                                    MSc    5      Mandatory
# 90     Fall 2022                                    MSc   10  Semi-Elective
# 91     Fall 2022                                    MSc   10       Elective
# 92     Fall 2022                                    MSc    5  Semi-Elective
# 93     Fall 2022                                    MSc    5       Elective
# 94     Fall 2022                                    MSc   10  Semi-Elective
# 95     Fall 2022                                    MSc   10       Elective
# 96     Fall 2022                                    MSc    5       Elective
# 97     Fall 2022                                    MSc    5  Semi-Elective
category_lists = {
    'managementAndBusiness': list(map(str, managementAndBusiness)),
    'medtec': list(map(str, medtec)),
    'manufacturingAndMaterials': list(map(str, manufacturingAndMaterials)),
    'designforpeople': list(map(str, designforpeople)),
    'supplychain': list(map(str, supplychain)),
    'productdesign': list(map(str, productdesign)),
    'systemsengineering': list(map(str, systemsengineering)),
    'circularitySustainability': list(map(str, circularitySustainability)),
    'SmartProducts': list(map(str, SmartProducts)),
    'tecnicalCompetences': list(map(str, tecnicalCompetences)) # Not just programming?
}

def find_categories(course):
    return [name for name, codes in category_lists.items() if course in codes]

CD['Category'] = CD['Course code'].apply(find_categories)
CD['Category'] = CD['Category'].apply(lambda x: ', '.join(x))

# %%
# If a course has the same name as another that already has a category assigned, the same category will be assigned
# Create a mapping from course name to category where Category is not empty
course_to_category = CD[CD["Category"] != ""].drop_duplicates(subset="Course name").set_index("Course name")["Category"]

# Use the mapping to fill missing categories based on course name
CD["Category"] = CD["Category"].replace("", None)  # replace empty string with actual NaN
CD["Category"] = CD["Category"].fillna(CD["Course name"].map(course_to_category))

# %% [markdown]
# #### Til Alex

# %%
# Viser hvilke der mangler ud fra category navn
df_missing_category = CD[CD["Category"].isna()]
df_missing_category_unique = df_missing_category.drop_duplicates(subset="Course name", keep="first").reset_index(drop=True)
df_missing_category_unique
# Out:
#    Course code                                        Course name  \
# 0        10605                              History of Technology
# 1        02502                                     Image analysis
# 2        02561                                  Computer Graphics
# 3        12240    Environmental Management, innovation and Ethics
# 4        41612                   Product design and documentation
# 5        41740               Digital Manufacturing - Industry 4.0
# 6        42101                Introduction to Operations Research
# 7        42587  Introduction to Operations and Supply Chain Ma...
# 8        02455                    Experiment in Cognitive Science
# 9        12605  Sustainability and Life Cycle Assessment in th...
# 10       41636                        Design for Circular Economy
# 11       41749                                Precision Machining
# 12       42893                           Psychology for engineers
# 13       46420                     Composite Materials and Fibres
# 14       12105                        Quantitative Sustainability
# 15       38109                                            X-Tech+
# 16       41615                                     Mechanical CAD
# 17       41656    Materials in advanced applications and products
# 18       02170                                   Database Systems
# 19       23552  Development of innovative future food: Ecotrop...
# 20       31070               Hands-on microcontroller programming
# 21       31386                  Building dependable robot systems
# 22       34346  Networking technologies and application develo...
# 23       41072                             Design for interaction
# 24       41083             Technology platforms and architectures
# 25       41635           Robust design of products and mechanisms
# 26       41655                       Advanced surface engineering
# 27       41737                         Design of plastic products
# 28       42090             Holistic Design of Engineering Systems
# 29       42282                                       Smart Cities
# 30       42340            Sustainability in engineering solutions
# 31       42373        Human factors and Implementation management
# 32       42380                             Supply Chain Analytics
# 33       42490  Technology, management, organisation and Busin...
# 34       42576                           From Analytics to Action
# 35       41512  Power transmitting machine elements - design a...
# 36       41739  Experimental plastic and metal processing tech...
# 37       42417                Simulation in Operations Management
# 38       42610                   Theory of Science in Engineering
# 39       02808  Personal Data Interaction for Mobile and Weara...
# 40       34315  Internet of things – application and infrastru...
# 41       34373  Mikrokontroller-programmering til avanceret Io...
# 42       42014               Environmental and Resource Economics
# 43       42386                            Entrepreneurial Finance
# 44       02806             Social data analysis and visualization
#
#        Semester Level ECTS    Course type Passed DI students  Passed students  \
# 0     Fall 2020   MSc    5       Elective                <=5             16.0
# 1     Fall 2022   BSc    5       Elective                <=5            294.0
# 2     Fall 2022   MSc    5       Elective                <=5             59.0
# 3     Fall 2022   MSc    5  Semi-Elective                <=5             93.0
# 4     Fall 2022   BSc   10       Elective                <=5             69.0
# 5     Fall 2022   MSc    5       Elective                <=5             49.0
# 6     Fall 2022   BSc    5       Elective                <=5            142.0
# 7     Fall 2022   BSc    5       Elective                <=5             93.0
# 8     Fall 2023   MSc    5       Elective                <=5             45.0
# 9     Fall 2023   BSc    5       Elective                <=5            161.0
# 10    Fall 2023   MSc    5      Mandatory                 17            189.0
# 11    Fall 2023   MSc    5       Elective                <=5             31.0
# 12    Fall 2023   MSc    5       Elective                  6             93.0
# 13    Fall 2023   MSc    5       Elective                <=5             29.0
# 14    Fall 2024   MSc    5      Mandatory                 19            481.0
# 15    Fall 2024   MSc   10       Elective                <=5             25.0
# 16    Fall 2024   BSc    5       Elective                <=5            126.0
# 17  Spring 2024   MSc   10       Elective                <=5             76.0
# 18  Spring 2020   BSc    5       Elective                <=5            194.0
# 19  Spring 2020   MSc    5       Elective                <=5             27.0
# 20  Spring 2020   MSc    5       Elective                <=5             32.0
# 21  Spring 2020   MSc    5       Elective                <=5             41.0
# 22  Spring 2020   MSc    5       Elective                <=5             19.0
# 23  Spring 2020   MSc    5       Elective                 41             43.0
# 24  Spring 2020   MSc    5  Semi-Elective                 34             68.0
# 25  Spring 2020   MSc    5  Semi-Elective                 30             72.0
# 26  Spring 2020   MSc    5       Elective                <=5             23.0
# 27  Spring 2020   MSc    5       Elective                 19             50.0
# 28  Spring 2020   MSc   10       Elective                 48             61.0
# 29  Spring 2020   MSc    5       Elective                <=5             53.0
# 30  Spring 2020   BSc    5       Elective                <=5             75.0
# 31  Spring 2020   MSc    5       Elective                <=5             38.0
# 32  Spring 2020   MSc    5       Elective                <=5             83.0
# 33  Spring 2020   MSc   10       Elective                <=5            467.0
# 34  Spring 2020   MSc    5       Elective                <=5             91.0
# 35  Spring 2021   MSc    5       Elective                <=5             42.0
# 36  Spring 2021   MSc    5       Elective                <=5             29.0
# 37  Spring 2021   MSc    5       Elective                <=5            152.0
# 38  Spring 2021   BSc    5       Elective                <=5            177.0
# 39  Spring 2022   MSc   10  Semi-Elective                <=5             59.0
# 40  Spring 2022   BSc    5       Elective                <=5             43.0
# 41  Spring 2022   MSc    5       Elective                <=5             14.0
# 42  Spring 2022   MSc    5       Elective                <=5            210.0
# 43  Spring 2022   MSc    5       Elective                  6             82.0
# 44  Spring 2023   MSc    5  Semi-Elective                <=5            146.0
#
#     Average grade Placement                                 URL  Eval_1.1  \
# 0              10      Fall  https://kurser.dtu.dk/course/10605       4.5
# 1             8.8      Fall  https://kurser.dtu.dk/course/02502       4.2
# 2             7.9      Fall  https://kurser.dtu.dk/course/02561       4.6
# 4        4.4       4.2       4.1       3.7       3.8      NaN
# 5        2.9       2.4       2.1       2.1       3.2      NaN
# 6        4.1       3.6       3.9       4.0       3.3      NaN
# 7        4.6       4.3       4.0       4.3       3.1      NaN
# 8        4.8       4.5       4.9       4.8       3.7      NaN
# 9        3.7       2.9       2.9       2.9       2.9      NaN
# 10       4.2       3.5       3.3       3.1       3.1      NaN
# 11       4.3       3.9       4.4       4.0       3.7      NaN
# 12       4.0       3.5       3.9       3.9       2.6      NaN
# 13       4.5       4.0       4.2       4.2       3.5      NaN
# 14       3.2       2.3       3.1       2.6       2.9      NaN
# 15       4.3       4.2       4.6       3.6       4.0      NaN
# 16       4.2       3.6       2.8       4.2       3.3      NaN
# 17       4.1       3.4       3.4       3.8       3.4      NaN
# 18       4.3       4.0       4.0       4.3       2.8      NaN
# 19       4.4       3.9       4.2       3.9       4.0      NaN
# 20       3.6       3.7       3.0       3.1       3.0      NaN
# 21       3.4       3.7       2.9       3.3       3.1      NaN
# 22       3.2       3.5       3.1       3.1       3.0      NaN
# 23       4.5       4.1       4.6       4.5       3.3      NaN
# 24       4.2       3.8       4.4       3.6       4.1      NaN
# 25       4.1       3.7       4.2       3.4       3.9      NaN
# 26       4.1       3.8       2.5       3.5       3.0      NaN
# 27       4.1       4.0       3.7       4.0       3.1      NaN
# 28       4.4       4.2       4.5       4.1       3.5      NaN
# 29       3.1       2.6       1.3       2.7       2.5      NaN
# 30       4.2       4.2       3.5       3.4       3.0      NaN
# 31       3.3       3.7       4.1       3.2       2.5      NaN
# 32       3.8       3.4       2.6       3.6       3.1      NaN
# 33       3.9       3.4       3.7       3.6       3.0      NaN
# 34       3.7       2.9       3.5       3.4       2.6      NaN
# 35       4.1       3.8       3.1       4.0       3.2      NaN
# 36       3.8       4.4       4.1       3.8       3.5      NaN
# 37       4.6       4.5       4.2       4.1       3.5      NaN
# 38       3.9       3.1       4.4       4.0       2.5      NaN
# 39       3.4       3.2       3.6       3.4       3.6      NaN
# 40       4.3       3.9       3.1       4.3       2.8      NaN
# 41       4.4       4.3       4.0       4.2       3.2      NaN
# 42       3.6       2.8       3.0       3.3       2.7      NaN
# 43       3.9       3.7       3.6       3.2       3.2      NaN
# 44       4.6       4.4       4.4       4.4       3.8      NaN

# %%
# Kan give row index på CD hvis du vil kryds tjekke
name = "Sustainability in management" #Ændrer denne her for at krydstjekke
matching_indices = CD.index[CD["Course name"] == name].tolist()
CD.iloc[matching_indices,:]
# Out:
#    Course code                   Course name   Semester Level ECTS  \
# 22       42351  Sustainability in management  Fall 2020   MSc    5
# 69       42351  Sustainability in management  Fall 2021   MSc    5
# 93       12771  Sustainability in management  Fall 2022   MSc    5
#
#    Course type Passed DI students  Passed students  Average grade Placement  \
# 22    Elective                  9            230.0            9.3      Fall
# 69    Elective                 29            189.0            9.9      Fall
# 93    Elective                 18            193.0  Pass/Non-Pass      Fall
#
#                                    URL  Eval_1.1  Eval_1.2  Eval_1.3  \
# 22  https://kurser.dtu.dk/course/42351       3.4       3.9       3.2
# 69  https://kurser.dtu.dk/course/42351       3.6       4.0       3.4
# 93  https://kurser.dtu.dk/course/12771       3.5       3.9       3.3
#
#     Eval_1.4  Eval_1.5  Eval_2.1               Category
# 22       4.0       3.4       2.8  managementAndBusiness
# 69       3.8       3.6       2.9  managementAndBusiness
# 93       4.0       3.8       3.1  managementAndBusiness

# %% [markdown]
# ## Evaluations

# %%
df_e = CD.copy()

# %%
df_e.dropna(subset=['Eval_1.1', 'Eval_1.2', 'Eval_1.3', 'Eval_1.4', 'Eval_1.5'], inplace=True)

# %%
semester_order = ["Fall 2024", "Spring 2024",
                 "Fall 2023", "Spring 2023",
                 "Fall 2022", "Spring 2022",
                 "Fall 2021", "Spring 2021",
                 "Fall 2020", "Spring 2020"]
semester_order = pd.Categorical(semester_order, categories=semester_order, ordered=True)

# %%
#Sorts out repeating courses by only having the rows of newest passed course
df_e['Semester'] = pd.Categorical(df_e['Semester'], categories=semester_order, ordered=True)
df_e_sorted = df_e.sort_values(by=['Course name', 'Semester'])
df_e = df_e_sorted.drop_duplicates(subset='Course name', keep='first')
df_e = df_e_sorted.drop_duplicates(subset='Course code', keep='first') # sorts out a few errors where the named differed slighly, but the course code is the same

# %%
#consolidating evaluations for those that are not time load related, excluding Eval_2.1
df_e["Evaluation"] = df_e[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5"]].mean(axis=1)
# Out:
# /var/folders/xl/ml65d5zn6dg23p6nqskls4dm0000gn/T/ipykernel_6274/3444246911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_e["Evaluation"] = df_e[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5"]].mean(axis=1)

# %%
df_e = df_e.drop(columns = ["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"])

# %%
df_e = df_e.sort_values(by='Evaluation', ascending=True)

# %%
df_e["Evaluation"] = round(df_e["Evaluation"], 2)

# %%
df_e = df_e.reset_index(drop=True)

# %%
from bokeh.models import TapTool, CustomJS, Div
from bokeh.layouts import column
from bokeh.io import output_file, show, save
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, WheelZoomTool
from bokeh.models import Range1d
from bokeh.models import Legend, LegendItem

# %%
# BOKEH

# Create ColumnDataSources
all_source = ColumnDataSource(df_e)
managementAndBuisness_source = ColumnDataSource(df_e[df_e['Category'].str.contains('managementAndBuisness', na=False)])
medtec_source = ColumnDataSource(df_e[df_e['Category'].str.contains('medtec', na=False)])
manufacturingAndMaterials_source = ColumnDataSource(df_e[df_e['Category'].str.contains('manufacturingAndMaterials', na=False)])
designforpeople_source = ColumnDataSource(df_e[df_e['Category'].str.contains('designforpeople', na=False)])
supplychain_source = ColumnDataSource(df_e[df_e['Category'].str.contains('supplychain', na=False)])
productdesign_source = ColumnDataSource(df_e[df_e['Category'].str.contains('productdesign', na=False)])
systemsengineering_source = ColumnDataSource(df_e[df_e['Category'].str.contains('systemsengineering', na=False)])
circularitySustainability_source = ColumnDataSource(df_e[df_e['Category'].str.contains('circularitySustainability', na=False)])
SmartProducts_source = ColumnDataSource(df_e[df_e['Category'].str.contains('SmartProducts', na=False)])
tecnicalCompetences_source = ColumnDataSource(df_e[df_e['Category'].str.contains('tecnicalCompetences', na=False)])

# Create a figure with custom axes labels
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=df_e["Course code"].unique().tolist(),
          width=1000,
          height =600)

# Create individual scatterplots
p.scatter(x="Course code", y='Evaluation', source=managementAndBuisness_source, legend_label="Management and Business",
          size=8, color="blue", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=medtec_source, legend_label="Medtech",
          size=8, color="green", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=manufacturingAndMaterials_source, legend_label="Manufacturing and Materials",
          size=8, color="red", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=designforpeople_source, legend_label="Design for People",
          size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=supplychain_source, legend_label="Supply Chain",
          size=8, color="orange", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=productdesign_source, legend_label="Product Design",
          size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=systemsengineering_source, legend_label="Systems Engineering",
          size=8, color="cyan", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=circularitySustainability_source, legend_label="Circularity and Sustainability",
          size=8, color="pink", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=SmartProducts_source, legend_label="Smart Products",
          size=8, color="brown", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=tecnicalCompetences_source, legend_label="Technical Competences",
          size=8, color="gray", alpha=0.6, marker="circle")

layout = column(p)

#Preactivate wheel zoom
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Plot style
p.xaxis.visible = True
p.legend.title = 'Learning categories'
p.legend.location = 'bottom_right'
p.legend.visible = True
p.legend.click_policy = 'hide'  # Clicking a legend item hides the corresponding data
p.xaxis.major_label_orientation = -0.785
#p.legend.spacing = 4

# Finalization
output_file("Evaluation_plot.html")
show(layout)
save(p)
# Out:
# '/Users/svend/Alex-Nielsen-manden.github.io/_Data load/Evaluation_plot.html'

# %% [markdown]
# ## Tap tool (fucking around)
# Implement more stuff to show when you click
# Assign legends as in assignment 2

# %%
#WORKS
from bokeh.models import ColumnDataSource, Range1d, WheelZoomTool, Div, CustomJS
from bokeh.plotting import figure, show, output_file, save
from bokeh.layouts import column
import pandas as pd

# Create ColumnDataSources
all_source = ColumnDataSource(df_e.sort_values(by=["Evaluation"]))
#managementAndBuisness_source = ColumnDataSource(df_e[df_e['Category'].str.contains('managementAndBuisness', na=False)])
#medtec_source = ColumnDataSource(df_e[df_e['Category'].str.contains('medtec', na=False)])
#manufacturingAndMaterials_source = ColumnDataSource(df_e[df_e['Category'].str.contains('manufacturingAndMaterials', na=False)])
#designforpeople_source = ColumnDataSource(df_e[df_e['Category'].str.contains('designforpeople', na=False)])
#supplychain_source = ColumnDataSource(df_e[df_e['Category'].str.contains('supplychain', na=False)])
#productdesign_source = ColumnDataSource(df_e[df_e['Category'].str.contains('productdesign', na=False)])
#systemsengineering_source = ColumnDataSource(df_e[df_e['Category'].str.contains('systemsengineering', na=False)])
#circularitySustainability_source = ColumnDataSource(df_e[df_e['Category'].str.contains('circularitySustainability', na=False)])
#SmartProducts_source = ColumnDataSource(df_e[df_e['Category'].str.contains('SmartProducts', na=False)])
#tecnicalCompetences_source = ColumnDataSource(df_e[df_e['Category'].str.contains('tecnicalCompetences', na=False)])

# Create figure
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=sorted(df_e["Course code"].unique().tolist()),
           width=1000,
           height=600,
           tools="tap")

# Scatter plots for each category
#p.scatter(x="Course code", y='Evaluation', source=managementAndBuisness_source, legend_label="Management and Business", size=8, color="blue", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=medtec_source, legend_label="Medtech", size=8, color="green", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=manufacturingAndMaterials_source, legend_label="Manufacturing and Materials", size=8, color="red", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=designforpeople_source, legend_label="Design for People",size=8, color="purple", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=supplychain_source, legend_label="Supply Chain",size=8, color="orange", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=productdesign_source, legend_label="Product Design",size=8, color="purple", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=systemsengineering_source, legend_label="Systems Engineering",size=8, color="cyan", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=circularitySustainability_source, legend_label="Circularity and Sustainability",size=8, color="pink", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=SmartProducts_source, legend_label="Smart Products",size=8, color="brown", alpha=0.6, marker="circle")
#p.scatter(x='Course code', y='Evaluation', source=tecnicalCompetences_source, legend_label="Technical Competences",size=8, color="gray", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=all_source, legend_label="All",size=8, color="gray", alpha=0.6, marker="circle")
# Styling
p.legend.title = 'Learning categories'
p.legend.location = 'bottom_right'
p.legend.visible = True
p.legend.click_policy = 'hide'
p.xaxis.major_label_orientation = -0.785
p.xaxis.visible = True

# Zoom tool setup
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Div to display course info
div = Div(text="Click on a course dot to see details", width=800)

# JS callback on full source
callback = CustomJS(args=dict(source=all_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")
all_source.selected.js_on_change('indices', callback)

# Final layout and display
layout = column(p, div)

output_file("Evaluation_plot.html")
show(layout)

# %%
#FUCKING AROUND

# %%
unique_categories_string = ", ".join(df_e['Category'].unique().astype(str))

# %%
#WORKS
from bokeh.models import ColumnDataSource, Range1d, WheelZoomTool, Div, CustomJS
from bokeh.plotting import figure, show, output_file, save
from bokeh.layouts import column
import pandas as pd

# Create ColumnDataSources
#all_source = ColumnDataSource(df_e.sort_values(by=["Evaluation"]))
managementAndBuisness_source = ColumnDataSource(df_e[df_e['Category'].str.contains('managementAndBuisness', na=False)])
medtec_source = ColumnDataSource(df_e[df_e['Category'].str.contains('medtec', na=False)])
manufacturingAndMaterials_source = ColumnDataSource(df_e[df_e['Category'].str.contains('manufacturingAndMaterials', na=False)])
designforpeople_source = ColumnDataSource(df_e[df_e['Category'].str.contains('designforpeople', na=False)])
supplychain_source = ColumnDataSource(df_e[df_e['Category'].str.contains('supplychain', na=False)])
productdesign_source = ColumnDataSource(df_e[df_e['Category'].str.contains('productdesign', na=False)])
systemsengineering_source = ColumnDataSource(df_e[df_e['Category'].str.contains('systemsengineering', na=False)])
circularitySustainability_source = ColumnDataSource(df_e[df_e['Category'].str.contains('circularitySustainability', na=False)])
SmartProducts_source = ColumnDataSource(df_e[df_e['Category'].str.contains('SmartProducts', na=False)])
tecnicalCompetences_source = ColumnDataSource(df_e[df_e['Category'].str.contains('tecnicalCompetences', na=False)])

# Create figure
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=sorted(df_e["Course code"].unique().tolist()),
           width=1000,
           height=600,
           tools="tap")

# Scatter plots for each category
#p.scatter(x='Course code', y='Evaluation', source=all_source, legend_label="All",size=8, color="gray", alpha=0.6, marker="circle")
p.scatter(x="Course code", y='Evaluation', source=managementAndBuisness_source, legend_label="Management and Business", size=8, color="blue", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=medtec_source, legend_label="Medtech", size=8, color="green", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=manufacturingAndMaterials_source, legend_label="Manufacturing and Materials", size=8, color="red", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=designforpeople_source, legend_label="Design for People",size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=supplychain_source, legend_label="Supply Chain",size=8, color="orange", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=productdesign_source, legend_label="Product Design",size=8, color="purple", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=systemsengineering_source, legend_label="Systems Engineering",size=8, color="cyan", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=circularitySustainability_source, legend_label="Circularity and Sustainability",size=8, color="pink", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=SmartProducts_source, legend_label="Smart Products",size=8, color="brown", alpha=0.6, marker="circle")
p.scatter(x='Course code', y='Evaluation', source=tecnicalCompetences_source, legend_label="Technical Competences",size=8, color="gray", alpha=0.6, marker="circle")


# Styling
p.legend.title = 'Learning categories'
p.legend.location = 'bottom_right'
p.legend.visible = True
p.legend.click_policy = 'mute'
p.xaxis.major_label_orientation = -0.785
p.xaxis.visible = True

# Zoom tool setup
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Div to display course info
div = Div(text="Click on a course dot to see details", width=800)

# Callbacks
callback1 = CustomJS(args=dict(source=managementAndBuisness_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")

callback2 = CustomJS(args=dict(source=medtec_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")

managementAndBuisness_source.selected.js_on_change('indices', callback1)
medtec_source.selected.js_on_change('indices', callback2)

# Final layout and display
layout = column(p, div)

output_file("Evaluation_plot.html")
show(layout)

# %%
#WORKS
from bokeh.models import ColumnDataSource, Range1d, WheelZoomTool, Div, CustomJS
from bokeh.plotting import figure, show, output_file, save
from bokeh.layouts import column
import pandas as pd

# Create ColumnDataSources
all_source = ColumnDataSource(df_e.sort_values(by=["Evaluation"]))

# Create figure
p = figure(title="Course Evaluation Tool",
           y_axis_label='Evaluation score (0-5)',
           x_axis_label="Course code",
           y_range=Range1d(2, 5),
           x_range=sorted(df_e["Course code"].unique().tolist()),
           width=1000,
           height=600,
           tools="tap")

# Scatter plots for each category
p.scatter(x='Course code', y='Evaluation', source=all_source, legend_label="All",size=8, color="red", alpha=0.6, marker="circle")


# Adjust title font size and style
p.title.text_font_size = "20pt"  # Increase title font size
p.title.text_font_style = "bold"  # Make title bold
p.title.text_font = "Arial"  # Change title font (optional)

# Adjust axis labels font size and style
p.xaxis.axis_label_text_font_size = "14pt"  # X-axis label size
p.yaxis.axis_label_text_font_size = "14pt"  # Y-axis label size
p.xaxis.axis_label_text_font_style = "normal"  # X-axis label style
p.yaxis.axis_label_text_font_style = "normal"  # Y-axis label style
p.xaxis.axis_label_text_font = "Arial"  # X-axis label font (optional)
p.yaxis.axis_label_text_font = "Arial"  # Y-axis label font (optional)

# Adjust tick labels font size
p.xaxis.major_label_text_font_size = "12pt"  # X-axis tick labels
p.yaxis.major_label_text_font_size = "12pt"  # Y-axis tick labels



# Legend
#p.legend.title = 'Learning categories'
#p.legend.location = 'bottom_right'
#p.legend.visible = True
#p.legend.click_policy = 'mute'
#p.xaxis.major_label_orientation = -0.785
#p.xaxis.visible = True

# Zoom tool setup
wheel_zoom_tool = WheelZoomTool()
p.add_tools(wheel_zoom_tool)
p.toolbar.active_scroll = wheel_zoom_tool

# Div to display course info
div = Div(text="Click on a course dot to see details", width=800)

# Callbacks
callback = CustomJS(args=dict(source=all_source, div=div), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const i = indices[0];
        const course = source.data['Course code'][i];
        const score = source.data['Evaluation'][i];
        const category = source.data['Category'][i];
        div.text = `<b>Course:</b> ${course} <br>
                    <b>Evaluation:</b> ${score} <br>
                    <b>Category:</b> ${category}`;
    }
""")

all_source.selected.js_on_change('indices', callback)

# Final layout and display
layout = column(p, div)

output_file("Evaluation_plot.html")
show(layout)

# %% [markdown]
# # Narrative

# %% [markdown]
# ## Categories and grades

# %%
df_n = CD.copy()

# Drop rows with any missing evaluation components
df_n.dropna(subset=['Eval_1.1', 'Eval_1.2', 'Eval_1.3', 'Eval_1.4', 'Eval_1.5'], inplace=True)

# Compute and round evaluation mean
df_n["Evaluation"] = df_n[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5"]].mean(axis=1).round(2)

# Convert grades to numeric and drop rows with missing values
df_n['Average grade'] = pd.to_numeric(df_n['Average grade'], errors='coerce')
df_n.dropna(subset=['Average grade', 'Evaluation'], inplace=True)

# Handle multi-category courses
df_n['Category'] = df_n['Category'].astype(str).str.split(',')
df_n = df_n.explode('Category')
df_n['Category'] = df_n['Category'].str.strip()
df_n = df_n[df_n['Category'].str.lower().isin(['', 'nan', 'none']) == False]

# Compute category-level averages
category_summary = df_n.groupby('Category')[['Average grade', 'Evaluation']].mean().reset_index()

# Prepare for plotting
category_summary = category_summary.sort_values(by='Average grade', ascending=False)
categories = category_summary['Category']
grades = category_summary['Average grade']
ratings = category_summary['Evaluation']
x = np.arange(len(categories))

# Dual-axis bar chart
fig, ax1 = plt.subplots(figsize=(14, 6))
bars1 = ax1.bar(x - 0.2, grades, width=0.4, label='Average Grade', color='steelblue')
ax1.set_ylabel('Average Grade (0–12)', color='steelblue')
ax1.set_ylim(0, 12)
ax1.tick_params(axis='y', labelcolor='steelblue')

ax2 = ax1.twinx()
bars2 = ax2.bar(x + 0.2, ratings, width=0.4, label='Average Evaluation', color='orange')
ax2.set_ylabel('Average Evaluation (0–5)', color='orange')
ax2.set_ylim(0, 5)
ax2.tick_params(axis='y', labelcolor='orange')

ax1.set_xticks(x)
ax1.set_xticklabels(categories, rotation=45, ha='right')
ax1.set_xlabel('Category')
plt.title('Comparison of Average Grade and Evaluation by Category (2020–2024)')

# Combine legends
ax1.legend([bars1, bars2], ['Average Grade', 'Average Evaluation'], loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Do the same but only for electives

# %%
df_n1 = CD.copy()

# Filter for elective courses
df_n1 = df_n1[df_n1['Course type'] == 'Elective']

# Drop rows with any missing evaluation components
df_n1.dropna(subset=['Eval_1.1', 'Eval_1.2', 'Eval_1.3', 'Eval_1.4', 'Eval_1.5'], inplace=True)

# Compute and round evaluation mean
df_n1["Evaluation"] = df_n1[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5"]].mean(axis=1).round(2)

# Convert grades to numeric and drop rows with missing values
df_n1['Average grade'] = pd.to_numeric(df_n1['Average grade'], errors='coerce')
df_n1.dropna(subset=['Average grade', 'Evaluation'], inplace=True)

# Handle multi-category courses
df_n1['Category'] = df_n1['Category'].astype(str).str.split(',')
df_n1 = df_n1.explode('Category')
df_n1['Category'] = df_n1['Category'].str.strip()
df_n1 = df_n1[df_n1['Category'].str.lower().isin(['', 'nan', 'none']) == False]

# Compute category-level averages
category_summary = df_n1.groupby('Category')[['Average grade', 'Evaluation']].mean().reset_index()

# Prepare for plotting
category_summary = category_summary.sort_values(by='Average grade', ascending=False)
categories = category_summary['Category']
grades = category_summary['Average grade']
ratings = category_summary['Evaluation']
x = np.arange(len(categories))

# Dual-axis bar chart
fig, ax1 = plt.subplots(figsize=(14, 6))
bars1 = ax1.bar(x - 0.2, grades, width=0.4, label='Average Grade', color='steelblue')
ax1.set_ylabel('Average Grade (0–12)', color='steelblue')
ax1.set_ylim(0, 12)
ax1.tick_params(axis='y', labelcolor='steelblue')

ax2 = ax1.twinx()
bars2 = ax2.bar(x + 0.2, ratings, width=0.4, label='Average Evaluation', color='orange')
ax2.set_ylabel('Average Evaluation (0–5)', color='orange')
ax2.set_ylim(0, 5)
ax2.tick_params(axis='y', labelcolor='orange')

ax1.set_xticks(x)
ax1.set_xticklabels(categories, rotation=45, ha='right')
ax1.set_xlabel('Category')
plt.title('Elective Courses: Average Grade and Evaluation by Category (2020–2024)')

# Combine legends
ax1.legend([bars1, bars2], ['Average Grade', 'Average Evaluation'], loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Average grade over time

# %%
df_n2 = CD.copy()

# Extract the year from the 'Semester' column
df_n2['Year'] = df_n2['Semester'].str.extract(r'(\d{4})').astype(int)

# Map the semesters (Fall/Spring) to numerical values for sorting
df_n2['Semester_Num'] = df_n2['Semester'].apply(lambda x: 1 if 'Spring' in x else 2)

# Combine 'Year' and 'Semester_Num' into a single time representation
df_n2['Time'] = df_n2['Year'] + (df_n2['Semester_Num'] - 1) * 0.5  # Spring = 0.0, Fall = 0.5

# Convert 'Average grade' to numeric, coercing errors to NaN
df_n2['Average grade'] = pd.to_numeric(df_n2['Average grade'], errors='coerce')

# Drop rows with missing 'Time' or 'Average grade'
df_n2.dropna(subset=['Time', 'Average grade'], inplace=True)

# Group by 'Time' and calculate average grade
grades_over_time = df_n2.groupby('Time')['Average grade'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))

# Plot the data with a line
plt.plot(grades_over_time['Time'], grades_over_time['Average grade'], marker='o', color='b', linestyle='-', linewidth=2)

# Title and labels
plt.title('Average Grade Over Time (Spring and Fall semesters)', fontsize=14)
plt.xlabel('Semester', fontsize=12)
plt.ylabel('Average Grade', fontsize=12)

# Set y-axis range from 0 to 12
plt.ylim(0, 12)

# Customize x-ticks to show both semester and year in a cleaner format
x_ticks = grades_over_time['Time']
x_labels = [f"Spring {int(t)}" if t % 1 == 0 else f"Fall {int(t)}" for t in x_ticks]
plt.xticks(x_ticks, labels=x_labels, rotation=45, ha='right', fontsize=10)

# Add data labels on the plot for each point
for i, row in grades_over_time.iterrows():
    plt.text(row['Time'], row['Average grade'] + 0.2, f"{row['Average grade']:.2f}",
             ha='center', va='bottom', fontsize=10, color='black')

# Display a grid for clarity
plt.grid(True)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Only electives

# %%
df_3 = CD.copy()

# Filter for electives
df_3 = df_3[df_3['Course type'] == 'Elective']

# Extract the year from the 'Semester' column
df_3['Year'] = df_3['Semester'].str.extract(r'(\d{4})').astype(int)

# Map the semesters (Fall/Spring) to numerical values for sorting
df_3['Semester_Num'] = df_3['Semester'].apply(lambda x: 1 if 'Spring' in x else 2)

# Combine 'Year' and 'Semester_Num' into a single time representation
df_3['Time'] = df_3['Year'] + (df_3['Semester_Num'] - 1) * 0.5  # Spring = 0.0, Fall = 0.5

# Convert 'Average grade' to numeric, coercing errors to NaN
df_3['Average grade'] = pd.to_numeric(df_3['Average grade'], errors='coerce')

# Drop rows with missing 'Time' or 'Average grade'
df_3.dropna(subset=['Time', 'Average grade'], inplace=True)

# Group by 'Time' and calculate average grade
grades_over_time = df_3.groupby('Time')['Average grade'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))

# Plot the data with a line
plt.plot(grades_over_time['Time'], grades_over_time['Average grade'], marker='o', color='b', linestyle='-', linewidth=2)

# Title and labels
plt.title('Average Grade Over Time (Electives)', fontsize=14)
plt.xlabel('Semester', fontsize=12)
plt.ylabel('Average Grade', fontsize=12)

# Set y-axis range from 0 to 12
plt.ylim(0, 12)

# Customize x-ticks to show both semester and year in a cleaner format
x_ticks = grades_over_time['Time']
x_labels = [f"Spring {int(t)}" if t % 1 == 0 else f"Fall {int(t)}" for t in x_ticks]
plt.xticks(x_ticks, labels=x_labels, rotation=45, ha='right', fontsize=10)

# Add data labels on the plot for each point
for i, row in grades_over_time.iterrows():
    plt.text(row['Time'], row['Average grade'] + 0.2, f"{row['Average grade']:.2f}",
             ha='center', va='bottom', fontsize=10, color='black')

# Display a grid for clarity
plt.grid(True)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Copy and filter for electives
df_n4 = CD.copy()
df_n4 = df_n4[df_n4['Course type'] == 'Elective']

# Drop rows with missing evaluations
df_n4.dropna(subset=['Eval_1.1', 'Eval_1.2', 'Eval_1.3', 'Eval_1.4', 'Eval_1.5'], inplace=True)

# Compute evaluation average
df_n4["Evaluation"] = df_n4[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5"]].mean(axis=1).round(2)

# Convert grades to numeric and drop incomplete rows
df_n4['Average grade'] = pd.to_numeric(df_n4['Average grade'], errors='coerce')
df_n4.dropna(subset=['Average grade', 'Evaluation'], inplace=True)

# Extract year from Semester
df_n4['Year'] = df_n4['Semester'].str.extract(r'(\d{4})')

# Handle multi-category courses
df_n4['Category'] = df_n4['Category'].astype(str).str.split(',')
df_n4 = df_n4.explode('Category')
df_n4['Category'] = df_n4['Category'].str.strip()
df_n4 = df_n4[df_n4['Category'].str.lower().isin(['', 'nan', 'none']) == False]

# Group by Category and Year
grouped = df_n4.groupby(['Year', 'Category'])[['Average grade', 'Evaluation']].mean().reset_index()

# Sort years for consistent subplot layout
years = sorted(grouped['Year'].dropna().unique())
num_years = len(years)
ncols = 2
nrows = int(np.ceil(num_years / ncols))

# Plot settings
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 5 * nrows), sharey=True)
axes = axes.flatten()

for i, year in enumerate(years):
    ax = axes[i]
    data = grouped[grouped['Year'] == year].sort_values(by='Average grade', ascending=False)
    x = np.arange(len(data))
    
    bars1 = ax.bar(x - 0.2, data['Average grade'], width=0.4, label='Grade', color='steelblue')
    bars2 = ax.bar(x + 0.2, data['Evaluation'], width=0.4, label='Evaluation', color='orange')
    
    ax.set_title(f"{year}", fontsize=12)
    ax.set_xticks(x)
    ax.set_xticklabels(data['Category'], rotation=45, ha='right')
    ax.set_ylim(0, 12)
    ax.set_ylabel('Score')
    ax.grid(True, axis='y', linestyle='--', alpha=0.6)
    
    # Add values above bars
    for j in range(len(data)):
        ax.text(x[j] - 0.2, data['Average grade'].iloc[j] + 0.2, f"{data['Average grade'].iloc[j]:.1f}", 
                ha='center', fontsize=8, color='steelblue')
        ax.text(x[j] + 0.2, data['Evaluation'].iloc[j] + 0.2, f"{data['Evaluation'].iloc[j]:.1f}", 
                ha='center', fontsize=8, color='orange')

    ax.legend(loc='upper right')

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle("Elective Courses: Grade and Evaluation by Category per Year", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Copy and filter for elective courses
df_n5 = CD.copy()
df_n5 = df_n5[df_n5['Course type'] == 'Elective']

# Convert relevant columns to numeric
df_n5['Passed students'] = pd.to_numeric(df_n5['Passed students'], errors='coerce')
df_n5['Passed DI students'] = pd.to_numeric(df_n5['Passed DI students'], errors='coerce')

# Drop rows with missing or zero values to avoid division errors
df_n5 = df_n5.dropna(subset=['Passed students', 'Passed DI students'])
df_n5 = df_n5[df_n5['Passed students'] > 0]

# Calculate fraction of DI students
df_n5['DI_fraction'] = df_n5['Passed DI students'] / df_n5['Passed students']

# Handle multi-category courses
df_n5['Category'] = df_n5['Category'].astype(str).str.split(',')
df_n5 = df_n5.explode('Category')
df_n5['Category'] = df_n5['Category'].str.strip()
df_n5 = df_n5[df_n5['Category'].str.lower().isin(['', 'nan', 'none']) == False]

# Compute mean DI fraction by category
popularity_by_category = df_n5.groupby('Category')['DI_fraction'].mean().reset_index()
popularity_by_category = popularity_by_category.sort_values(by='DI_fraction', ascending=False)

# Plot
plt.figure(figsize=(12, 6))
bars = plt.bar(popularity_by_category['Category'], popularity_by_category['DI_fraction'], color='mediumseagreen')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Fraction of Passed DI Students')
plt.xlabel('Category')
plt.title('Elective Courses: Popularity by Category (Fraction of DI Students)')
plt.ylim(0, 1)

# Annotate bars with values
for bar in bars:
    height = bar.get_height()
    plt.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Copy and filter for elective courses
df_n6 = CD.copy()
df_n6 = df_n6[df_n6['Course type'] == 'Elective']

# Convert relevant columns to numeric
df_n6['Passed students'] = pd.to_numeric(df_n6['Passed students'], errors='coerce')
df_n6['Passed DI students'] = pd.to_numeric(df_n6['Passed DI students'], errors='coerce')

# Drop rows with missing or zero values to avoid division errors
df_n6 = df_n6.dropna(subset=['Passed students', 'Passed DI students'])
df_n6 = df_n6[df_n6['Passed students'] > 0]

# Calculate fraction of DI students
df_n6['DI_fraction'] = df_n6['Passed DI students'] / df_n6['Passed students']

# Handle multi-category courses
df_n6['Category'] = df_n6['Category'].astype(str).str.split(',')
df_n6 = df_n6.explode('Category')
df_n6['Category'] = df_n6['Category'].str.strip()
df_n6 = df_n6[df_n6['Category'].str.lower().isin(['', 'nan', 'none']) == False]

# Extract year from semester string like "Fall 2023"
df_n6['Year'] = df_n6['Semester'].str.extract(r'(\d{4})')
df_n6 = df_n6.dropna(subset=['Year'])

# Prepare plot
years = sorted(df_n6['Year'].unique())
n_years = len(years)
n_cols = 3
n_rows = int(np.ceil(n_years / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 6, n_rows * 5), sharey=True)
axes = axes.flatten()

for i, year in enumerate(years):
    ax = axes[i]
    df_year = df_n6[df_n6['Year'] == year]
    summary = df_year.groupby('Category')['DI_fraction'].mean().reset_index()
    summary = summary.sort_values(by='DI_fraction', ascending=False)

    bars = ax.bar(summary['Category'], summary['DI_fraction'], color='mediumseagreen')
    ax.set_title(f'{year}')
    ax.set_ylim(0, 1)
    ax.set_xticklabels(summary['Category'], rotation=45, ha='right')
    
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

# Remove empty subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

fig.suptitle('Elective Course Popularity by Category (Fraction of DI Students per Year)', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# /var/folders/xl/ml65d5zn6dg23p6nqskls4dm0000gn/T/ipykernel_6274/3722667129.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(summary['Category'], rotation=45, ha='right')
# /var/folders/xl/ml65d5zn6dg23p6nqskls4dm0000gn/T/ipykernel_6274/3722667129.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(summary['Category'], rotation=45, ha='right')
# /var/folders/xl/ml65d5zn6dg23p6nqskls4dm0000gn/T/ipykernel_6274/3722667129.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(summary['Category'], rotation=45, ha='right')
# /var/folders/xl/ml65d5zn6dg23p6nqskls4dm0000gn/T/ipykernel_6274/3722667129.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(summary['Category'], rotation=45, ha='right')
# /var/folders/xl/ml65d5zn6dg23p6nqskls4dm0000gn/T/ipykernel_6274/3722667129.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(summary['Category'], rotation=45, ha='right')
