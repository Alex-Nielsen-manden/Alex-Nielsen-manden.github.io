# %% [markdown]
# #### READ ME
# It took me approximately 5000 sec to execute the whole df.\
# If you just desire a proof of concept, consider changing the value of df_length in cell 17 to load data for a smaller range.

# %% [markdown]
# ## DESIGN & INNOVATION COURSE DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Unfolds the whole dataframe
pd.set_option('display.max_rows', None) # Show all rows
pd.set_option('display.max_columns', None) # Show all columns
pd.set_option('display.max_colwidth', None) # If your DataFrame has long text values, widen the column display

# %%
#Import D&I data
df = pd.read_excel("DI_courses_2020-24.xlsx")

# %%
#Renaming the columns
df.columns = ["Semester", "Course code", "Course name", "Passed DI students", "Average grade"]

# %%
# Adding columns
df[["Course type", "School year", "ECTS", "Level", "Passed students"]] = ""

# %%
# Eliminate special courses
df = df[df["Course code"].astype(str).str.match(r"^\d{5}$")] # Eliminates everything but 5 digit course codes
df = df.reset_index(drop=True)

# %%
# Removes invalid course codes: 99999
df = df[df["Course code"] != "99999"].reset_index(drop=True)

# %%
# Changing the anonymized data for passed students
df['Passed DI students'] = df['Passed DI students'].replace('<= 5 personer', '<=5')

# %%
# Defines course types for DI students
mandatory = ["12100", "12106", "12105", "12101", "42505", "42503", "42502", #Polytechnical foundation
             "41636", "41639", "02809", "38110"] #Programme specific

semi = ["02830", "34365", "34366", "34367", "38113", "41073", "41083", "41084", "41635", "41637", "41638", "63851", #Course Group 1: Systematic Design
       "02266", "02806", "02808", "12240", "12250", "12772", "38102", "38103", "38108", "41636"] #Course Group 2: Design for People & Society

for i in range(len(df)):
    if df.loc[i, "Course code"] in mandatory:
        df.loc[i, "Course type"] = "Mandatory"
        
    elif df.loc[i, "Course code"] in semi:
        df.loc[i, "Course type"] = "Semi-Elective"

    else:
        df.loc[i, "Course type"] = "Elective"

# %%
# Changing the Semester column from Danish to English to be used in the grade_url
df["Term"] = df["Semester"] # Adds the column

# Spring first, in order not to confuse with forår
df['Term'] = df['Term'].replace('F20', 'Summer-2020') #Spring 20
df['Term'] = df['Term'].replace('F21', 'Summer-2021') #Spring 21
df['Term'] = df['Term'].replace('F22', 'Summer-2022') #Spring 22
df['Term'] = df['Term'].replace('F23', 'Summer-2023') #Spring 23
df['Term'] = df['Term'].replace('F24', 'Summer-2024') #Spring 24

# Fall secondly
df['Term'] = df['Term'].replace('E19', 'Winter-2019') #Fall 19
df['Term'] = df['Term'].replace('E20', 'Winter-2020') #Fall 20
df['Term'] = df['Term'].replace('E21', 'Winter-2021') #Fall 21
df['Term'] = df['Term'].replace('E22', 'Winter-2022') #Fall 22
df['Term'] = df['Term'].replace('E23', 'Winter-2023') #Fall 23
df['Term'] = df['Term'].replace('E24', 'Winter-2024') #Fall 24

# %%
# Adding the school year (will be used for the year url)
df["School year"] = df["Semester"] # Redefines the column

# Spring
df['School year'] = df['School year'].replace('F20', "2019-2020") #Spring 20
df['School year'] = df['School year'].replace('F21', "2020-2021") #Spring 21
df['School year'] = df['School year'].replace('F22', "2021-2022") #Spring 22
df['School year'] = df['School year'].replace('F23', "2022-2023") #Spring 23
df['School year'] = df['School year'].replace('F24', "2023-2024") #Spring 24

# Fall
df['School year'] = df['School year'].replace('E19', "2019-2020") #Fall 19
df['School year'] = df['School year'].replace('E20', "2020-2021") #Fall 20
df['School year'] = df['School year'].replace('E21', "2021-2022") #Fall 21
df['School year'] = df['School year'].replace('E22', "2022-2023") #Fall 22
df['School year'] = df['School year'].replace('E23', "2023-2024") #Fall 23
df['School year'] = df['School year'].replace('E24', "2024-2025") #Fall 24

# %% [markdown]
# ## NETSCRAPING GENERAL COURSE DATA

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# %%
# Function that can load an html
def extract_html(url):
    options = Options()
    options.add_argument('--headless')
    driver = webdriver.Chrome(options=options)
    
    # Extracts html from the url and make it readable
    driver.get(url)
    time.sleep(2)  # Let JS load
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    driver.quit()
    
    return soup

# %%
# Can be changed to lower the loading time from netscraping
df_length = len(df)

# %%
# Add the URLs to df
df[["URL", "Year_URL", "Grade_URL"]] = "" #Creating new columns

for i in range(df_length):
    url = f"https://kurser.dtu.dk/course/{df.iloc[i]["Course code"]}"
    df.loc[i, "URL"] = url #assigns url to df
    
    year = df.loc[i,"School year"]
    year_url = f"https://kurser.dtu.dk/course/{year}/{df.iloc[i]["Course code"]}" #creates the individual urls
    df.loc[i, "Year_URL"] = year_url #assigns url to df

    grade_url = f"https://karakterer.dtu.dk/Histogram/1/{df["Course code"][i]}/{df["Term"][i]}" #https://karakterer.dtu.dk/Histogram/1/02809/Winter-2024
    df.loc[i, "Grade_URL"] = grade_url #assigns grade_url to df

# %%
df
# Out:
#     Semester Course code  \
# 0        E19       02266
# 1        E19       02633
# 2        E20       02266
# 3        E20       02393
# 4        E20       02450
# 5        E20       02809
# 6        E20       10316
# 7        E20       10605
# 8        E20       22435
# 9        E20       27002
# 10       E20       28870
# 11       E20       31385
# 12       E20       34365
# 13       E20       41051
# 14       E20       41073
# 15       E20       41084
# 16       E20       41628
# 17       E20       41743
# 18       E20       42071
# 19       E20       42081
# 20       E20       42085
# 21       E20       42087
# 22       E20       42351
# 23       E20       42372
# 24       E20       42383
# 25       E20       42387
# 26       E20       42388
# 27       E20       42389
# 28       E20       42390
# 29       E20       42430
# 30       E20       42435
# 31       E20       42436
# 32       E20       42451
# 33       E20       42452
# 34       E20       42575
# 35       E20       42577
# 36       E20       42634
# 37       E20       42879
# 38       E20       88383
# 39       E21       02266
# 40       E21       02441
# 41       E21       02492
# 42       E21       02631
# 43       E21       02633
# 44       E21       02809
# 45       E21       02830
# 46       E21       11337
# 47       E21       12130
# 48       E21       12132
# 49       E21       12139
# 50       E21       22700
# 51       E21       28213
# 52       E21       31383
# 53       E21       31385
# 54       E21       34052
# 55       E21       34338
# 56       E21       34365
# 57       E21       34366
# 58       E21       34540
# 59       E21       41073
# 60       E21       41084
# 61       E21       41628
# 62       E21       41742
# 63       E21       41743
# 64       E21       41744
# 65       E21       42081
# 66       E21       42085
# 67       E21       42087
# 68       E21       42115
# 69       E21       42351
# 70       E21       42372
# 71       E21       42390
# 72       E21       42402
# 73       E21       42430
# 74       E21       42435
# 75       E21       42436
# 76       E21       42451
# 77       E21       42502
# 231      F20       34346
# 232      F20       41072
# 233      F20       41078
# 234      F20       41083
# 235      F20       41501
# 236      F20       41514
# 237      F20       41618
# 238      F20       41635
# 239      F20       41655
# 240      F20       41656
# 241      F20       41665
# 242      F20       41737
# 243      F20       42083
# 244      F20       42085
# 245      F20       42090
# 246      F20       42107
# 247      F20       42196
# 248      F20       42282
# 249      F20       42340
# 250      F20       42371
# 251      F20       42373
# 252      F20       42380
# 253      F20       42429
# 254      F20       42433
# 255      F20       42438
# 256      F20       42490
# 257      F20       42576
# 258      F20       42634
# 259      F21       02102
# 260      F21       02160
# 261      F21       02393
# 262      F21       02431
# 263      F21       02450
# 264      F21       02631
# 265      F21       10420
# 266      F21       10603
# 267      F21       22281
# 268      F21       22284
# 269      F21       23552
# 270      F21       28864
# 271      F21       31386
# 272      F21       34346
# 273      F21       41072
# 274      F21       41083
# 275      F21       41511
# 276      F21       41512
# 277      F21       41522
# 278      F21       41571
# 279      F21       41615
# 280      F21       41635
# 281      F21       41656
# 282      F21       41669
# 283      F21       41737
# 284      F21       41739
# 285      F21       42090
# 286      F21       42270
# 287      F21       42282
# 288      F21       42340
# 289      F21       42370
# 290      F21       42373
# 291      F21       42415
# 292      F21       42417
# 293      F21       42429
# 294      F21       42433
# 295      F21       42490
# 296      F21       42505
# 297      F21       42576
# 298      F21       42610
# 299      F21       42634
# 300      F21       88383
# 301      F22       02170
# 302      F22       02411
# 303      F22       02450
# 304      F22       02631
# 305      F22       02633
# 306      F22       02808
# 307      F22       10603
# 308      F22       23552
# 309      F22       31375
# 310      F22       31386
# 311      F22       31392
# 312      F22       34315
# 313      F22       34346
# 314      F22       34373
# 315      F22       41028
# 316      F22       41031
# 317      F22       41061
# 318      F22       41083
# 319      F22       41615
# 320      F22       41635
# 321      F22       41656
# 322      F22       41737
# 323      F22       41739
# 324      F22       42014
# 325      F22       42090
# 326      F22       42105
# 327      F22       42282
# 328      F22       42340
# 329      F22       42375
# 330      F22       42378
# 331      F22       42380
# 332      F22       42386
# 333      F22       42391
# 334      F22       42392
# 335      F22       42417
# 336      F22       42429
# 337      F22       42433
# 338      F22       42502
# 339      F22       42505
# 340      F22       42543
# 341      F22       42634
# 342      F23       01035
# 343      F23       02105
# 344      F23       02450
# 345      F23       02631
# 346      F23       02633
# 347      F23       02806
# 348      F23       02808
# 349      F23       10603
# 350      F23       12143
# 351      F23       12205
# 352      F23       12773
# 353      F23       34346
# 354      F23       34373
# 355      F23       38103
# 356      F23       38104
# 357      F23       38106
# 358      F23       38301
# 359      F23       41083
# 360      F23       41512
# 361      F23       41615
# 362      F23       41635
# 363      F23       41656
# 364      F23       41659
# 365      F23       41737
# 366      F23       42014
# 367      F23       42090
# 368      F23       42417
# 369      F23       42429
# 370      F23       42433
# 371      F23       42503
# 372      F23       42505
# 373      F23       42543
# 374      F23       42610
# 375      F23       46760
# 376      F24       02450
# 377      F24       02502
# 378      F24       02806
# 379      F24       02808
# 380      F24       10603
# 381      F24       10862
# 382      F24       12211
# 383      F24       12773
# 384      F24       12953
# 385      F24       23532
# 386      F24       27510
# 387      F24       34315
# 388      F24       34755
# 389      F24       38001
# 390      F24       38103
# 391      F24       38104
# 392      F24       38106
# 393      F24       38109
# 394      F24       38302
# 395      F24       41083
# 396      F24       41342
# 397      F24       41528
# 398      F24       41615
# 399      F24       41635
# 400      F24       41639
# 401      F24       41735
# 402      F24       41737
# 403      F24       41739
# 404      F24       42016
# 405      F24       42101
# 406      F24       42503
# 407      F24       42505
# 408      F24       42543
# 409      F24       46797
# 410      F24       63851
# 411      F24       88383
#
#                                                                                           Course name  \
# 0                                                                   02266 User experience engineering
# 1                                              02633 Introduktion til programmering og databehandling
# 2                                                                   02266 User experience engineering
# 3                                                                           02393 Programmering i C++
# 4                                              02450 Introduktion til machine learning og data mining
# 5                                                                  02809 UX design prototypeudvikling
# 6                                       10316 Materialedesign med maskinlæring og kunstig intelligens
# 7                                                                             10605 Teknologihistorie
# 8                                                                22435 Medikoteknisk produktudvikling
# 9                                                                                  27002 Life science
# 10                                                                      28870 Energi og bæredygtighed
# 11                                                                       31385 Autonome robotsystemer
# 12                                                            34365 Prototyper for internet of things
# 13                                                                   41051 Produktliv og miljøforhold
# 14                                               41073 Udvikling og drift af produkt/service-systemer
# 15                                                                  41084 Biologisk inspireret design
# 16                                                                            41628 Konceptualisering
# 17                                                 41743 Mikro produktdesign, udvikling og produktion
# 18                                             42071 Design og udvikling i en organisatorisk kontekst
# 19                                                 42081 Iscenesættelse og co-creation og kreativitet
# 20                                                          42085 Forretningsdesign til bæredygtighed
# 21                                                       42087 Design Methods and Reflective Practice
# 22                                                                      42351 Bæredygtighed i ledelse
# 23                                                 42372 Livscyklusvurdering af produkter og systemer
# 24                                                                  42383 Entrepreneurial Life Skills
# 25                                                            42387 Digitale trends for entreprenører
# 26                                                                42388 Due diligence of new ventures
# 27                                                                          42389 Feasibility studies
# 28                                 42390 Teknologiers rolle i bæredygtig omstilling og klimaindsatsen
# 29                                                                               42430 Projektledelse
# 30                                                                             42435 Virksomhedsstart
# 31                                                                     42436 Teknologisk Iværksætteri
# 32                                      42451 Mass customization - anvendelse af produktkonfigurering
# 33                                                                        42452 Complexity management
# 34                                                              42575 Teknologi og innovationsledelse
# 35                                                          42577 Introduktion til business analytics
# 36                                                                      42634 X-Tech entrepreneurship
# 37                                                    42879 Beslutningsstøtte og strategisk vurdering
# 38                           88383 Akademisk informationssøgning - styrk dine informationskompetencer
# 39                                                                  02266 User experience engineering
# 40                                                   02441 Anvendt statistik og statistisk programmel
# 41                                             02492 Digital learning technology and entrepreneurship
# 42                                             02631 Introduktion til programmering og databehandling
# 43                                             02633 Introduktion til programmering og databehandling
# 44                                                                 02809 UX design prototypeudvikling
# 45                                                02830 Avanceret projekt i digitale medieteknologier
# 46                                                                            11337 Agile prototyping
# 47                                                          12130 Affaldssystemer og affaldsteknologi
# 48                                                           12132 LCA-modellering af affaldssystemer
# 49                                                                         12139 Resource Engineering
# 50                                                              22700 Effective science communication
# 51                                                                             28213 Polymerteknologi
# 52                                                                                  31383 Robotteknik
# 53                                                                       31385 Autonome robotsystemer
# 54                                                                            34052 Ikke-lineær optik
# 55                                       34338 Telekommunikations programmeringsprojekter med Arduino
# 56                                                            34365 Prototyper for internet of things
# 57                                                                        34366 Intelligente systemer
# 58                                     34540 Lysemitterende dioder og solceller til energianvendelser
# 59                                               41073 Udvikling og drift af produkt/service-systemer
# 60                                                                  41084 Biologisk inspireret design
# 61                                                                            41628 Konceptualisering
# 62                                    41742 Introduktion til mikromekanisk systemdesign og produktion
# 63                                                 41743 Mikro produktdesign, udvikling og produktion
# 64                                                           41744 Præcisionsfremstillingsteknologier
# 65                                                 42081 Iscenesættelse og co-creation og kreativitet
# 66                                                          42085 Forretningsdesign til bæredygtighed
# 67                                                       42087 Design Methods and Reflective Practice
# 68                                                                           42115 Netværksoptimering
# 69                                                                      42351 Bæredygtighed i ledelse
# 70                                                 42372 Livscyklusvurdering af produkter og systemer
# 71                                 42390 Teknologiers rolle i bæredygtig omstilling og klimaindsatsen
# 72                                    42402 Bæredygtig operations- og supply chain management (O&SCM)
# 73                                                                               42430 Projektledelse
# 74                                                                             42435 Virksomhedsstart
# 75                                                                     42436 Teknologisk Iværksætteri
# 76                                      42451 Mass customization - anvendelse af produktkonfigurering
# 77                                           42502 Facilitating innovation in multidisciplinary teams
# 78                                                 42554 Social entrepreneurship: theory and practice
# 79                                                              42575 Teknologi og innovationsledelse
# 80                                                                      42634 X-Tech entrepreneurship
# 81                                                    42879 Beslutningsstøtte og strategisk vurdering
# 82                                                                       47203 Design-build 3: solovn
# 83                                                                  02266 User experience engineering
# 84                                             02450 Introduktion til machine learning og data mining
# 85                                             02492 Digital learning technology and entrepreneurship
# 86                                                                                02502 Billedanalyse
# 87                                                                               02561 Computergrafik
# 88                                                              02805 Sociale grafer og interaktioner
# 89                                                                 02809 UX design prototypeudvikling
# 90                                                02830 Avanceret projekt i digitale medieteknologier
# 91                                                       12104 Modellering af miljøtekniske processer
# 92                                                          12240 Miljømanagement, innovation og etik
# 93                                                                      12771 Bæredygtighed i ledelse
# 94                                                 12772 Livscyklusvurdering af produkter og systemer
# 95                                                         22475 Vævs- og bevægeapparatets biomekanik
# 96         25301 Introduktion til akvatiske økosystemer, antropogene trusler og bæredygtige løsninger
# 97                                                            34365 Prototyper for internet of things
# 98                                                                             38101 Virksomhedsstart
# 99                                                                      38103 X-Tech Entrepreneurship
# 100                                                           38105 Digitale trends for entreprenører
# 101                                                         38107 Forretningsdesign til bæredygtighed
# 102                                                             38108 Teknologi og innovationsledelse
# 103                                                                  41051 Produktliv og miljøforhold
# 104                                              41073 Udvikling og drift af produkt/service-systemer
# 105                                                                 41084 Biologisk inspireret design
# 106                                                        41612 Produktkonstruktion og dokumentation
# 107                                                                           41628 Konceptualisering
# 108                                     41637 Mass customization - anvendelse af produktkonfigurering
# 109                                                                       41638 Complexity management
# 110                                                              41653 Korrosion (teori og teknologi)
# 111                                    41733 Metallurgi, design og fremstilling af støbte komponenter
# 112                                                         41740 Digital fremstilling - Industri 4.0
# 294                           42433 Avanceret ledelse af ingeniørprojekter, programmer og porteføljer
# 295                                     42490 Teknologi, ledelse, organisation og forretningsmodeller
# 296                                          42505 Facilitating innovation in multidisciplinary teams
# 297                                                                    42576 From Analytics to Action
# 298                                                              42610 Ingeniørfagets videnskabsteori
# 299                                                                     42634 X-Tech entrepreneurship
# 300                          88383 Akademisk informationssøgning - styrk dine informationskompetencer
# 301                                                                            02170 Databasesystemer
# 302                                                               02411 Statistisk forsøgsplanlægning
# 303                                            02450 Introduktion til machine learning og data mining
# 304                                            02631 Introduktion til programmering og databehandling
# 305                                            02633 Introduktion til programmering og databehandling
# 306                                                                   02808 Personal data interaction
# 307   10603 Vidensskabelse og videnscirkulation. Hvordan vidste Edison og Newton - og hvordan ved du?
# 308                     23552 Development of innovative future food: Ecotrophelia and Blue Dot course
# 309               31375 Playware teknologi - programmering af app-kontrol af legende indlejret system
# 310                                                          31386 Design af pålidelige robotsystemer
# 311                                                            31392 Perception for autonome systemer
# 312                                 34315 Internet of things - applikation og infrastruktur udvikling
# 313                   34346 Netværksteknologier og applikationsudvikling til Internet of Things (IoT)
# 314                              34373 Mikrokontroller-programmering til avanceret IoT med embedded C
# 315                                                           41028 Design af mekatroniske systemer 1
# 316                                                                        41031 Industrielt design 1
# 317                                                                        41061 Arenaer og koncepter
# 318                                                      41083 Teknologiske platforme og arkitekturer
# 319                                                                                41615 Mekanisk CAD
# 320                                                    41635 Robust design af produkter og mekanismer
# 321                                            41656 Materialer i avancerede anvendelser og produkter
# 322                                                                                 41737 Plastdesign
# 323                                                41739 Eksperimentel plast og metal procesteknologi
# 324                                                                    42014 Miljø-og resourceøkonomi
# 325                                                        42090 Helhedsdesign af engineering systems
# 326                                                                       42105 Finansielle produkter
# 327                                                                                 42282 Smarte byer
# 328                                                           42340 Bæredygtighed i ingeniørløsninger
# 329                                                               42375 Avanceret livscyklusvurdering
# 330                                   42378 Evaluering af sundheds-, miljø- og livscykluspåvirkninger
# 331                                                                      42380 Supply chain analytics
# 332                                                                    42386 Økonomi for iværksættere
# 333                                                                                     42391 SDG Lab
# 334                                        42392 Udvikling af iværksætter mindset gennem seriøse spil
# 335                                                          42417 Simulering i operations management
# 336                                                                              42429 Projektledelse
# 337                           42433 Avanceret ledelse af ingeniørprojekter, programmer og porteføljer
# 338                                          42502 Facilitating innovation in multidisciplinary teams
# 339                                          42505 Facilitating innovation in multidisciplinary teams
# 340                                                        42543 Ledelse af organisatorisk forandring
# 341                                                                     42634 X-Tech entrepreneurship
# 342                                                                                 01035 Matematik 2
# 343                                                              02105 Algoritmer og datastrukturer 1
# 344                                            02450 Introduktion til machine learning og data mining
# 345                                            02631 Introduktion til programmering og databehandling
# ...
# 158  https://karakterer.dtu.dk/Histogram/1/41749/Winter-2023
# 159  https://karakterer.dtu.dk/Histogram/1/41938/Winter-2023
# 160  https://karakterer.dtu.dk/Histogram/1/42402/Winter-2023
# 161  https://karakterer.dtu.dk/Histogram/1/42502/Winter-2023
# 162  https://karakterer.dtu.dk/Histogram/1/42577/Winter-2023
# 382  https://karakterer.dtu.dk/Histogram/1/12211/Summer-2024
# 383  https://karakterer.dtu.dk/Histogram/1/12773/Summer-2024
# 384  https://karakterer.dtu.dk/Histogram/1/12953/Summer-2024
# 385  https://karakterer.dtu.dk/Histogram/1/23532/Summer-2024
# 386  https://karakterer.dtu.dk/Histogram/1/27510/Summer-2024
# 387  https://karakterer.dtu.dk/Histogram/1/34315/Summer-2024
# 388  https://karakterer.dtu.dk/Histogram/1/34755/Summer-2024
# 389  https://karakterer.dtu.dk/Histogram/1/38001/Summer-2024
# 390  https://karakterer.dtu.dk/Histogram/1/38103/Summer-2024
# 391  https://karakterer.dtu.dk/Histogram/1/38104/Summer-2024
# 392  https://karakterer.dtu.dk/Histogram/1/38106/Summer-2024
# 393  https://karakterer.dtu.dk/Histogram/1/38109/Summer-2024
# 394  https://karakterer.dtu.dk/Histogram/1/38302/Summer-2024
# 395  https://karakterer.dtu.dk/Histogram/1/41083/Summer-2024
# 396  https://karakterer.dtu.dk/Histogram/1/41342/Summer-2024
# 397  https://karakterer.dtu.dk/Histogram/1/41528/Summer-2024
# 398  https://karakterer.dtu.dk/Histogram/1/41615/Summer-2024
# 399  https://karakterer.dtu.dk/Histogram/1/41635/Summer-2024
# 400  https://karakterer.dtu.dk/Histogram/1/41639/Summer-2024
# 401  https://karakterer.dtu.dk/Histogram/1/41735/Summer-2024
# 402  https://karakterer.dtu.dk/Histogram/1/41737/Summer-2024
# 403  https://karakterer.dtu.dk/Histogram/1/41739/Summer-2024
# 404  https://karakterer.dtu.dk/Histogram/1/42016/Summer-2024
# 405  https://karakterer.dtu.dk/Histogram/1/42101/Summer-2024
# 406  https://karakterer.dtu.dk/Histogram/1/42503/Summer-2024
# 407  https://karakterer.dtu.dk/Histogram/1/42505/Summer-2024
# 408  https://karakterer.dtu.dk/Histogram/1/42543/Summer-2024
# 409  https://karakterer.dtu.dk/Histogram/1/46797/Summer-2024
# 410  https://karakterer.dtu.dk/Histogram/1/63851/Summer-2024
# 411  https://karakterer.dtu.dk/Histogram/1/88383/Summer-2024

# %%
# Adds the values from the course base

for i in range(df_length):
    if i == 115:
        df.loc[i, "Course name"] = "Staging co-creation and creativity"
        df.loc[i, "ECTS"] = "5"
        df.loc[i, "Level"] = "MSc"

    else:    
        url = df.loc[i,"Year_URL"]
        soup = extract_html(url)
    
        # Course names in English 
        titles = soup.find_all("title")
        for title in titles:
            name = title.get_text()
        df.loc[i, "Course name"] = name
    
        # ECTS points
        #print(i)
        label_cell = soup.find('td', string=lambda text: text and "Point( ECTS )" in text)
        ects = label_cell.find_next_sibling('td').text.strip()
        print(i)
        df.loc[i, "ECTS"] = ects
    
        # Course level (BSc, MSc)
        label_cell = soup.find('label', string=lambda text: text and "Course type" in text)
        course_type_td = label_cell.find_parent('td').find_next_sibling('td')
        course_type = course_type_td.find_all('div')[0].text.strip()
        df.loc[i, "Level"] = course_type
# Out:
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\socket.py:850, in create_connection(address, timeout, source_address, all_errors)
#     849     sock.bind(source_address)
# --> 850 sock.connect(sa)
#     851 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 11
#       9 else:
#      10     url = df.loc[i,"Year_URL"]
# ---> 11     soup = extract_html(url)
#      13     # Course names in English
#      14     titles = soup.find_all("title")
#
# Cell In[16], line 12, in extract_html(url)
#      10 html = driver.page_source
#      11 soup = BeautifulSoup(html, 'html.parser')
# ---> 12 driver.quit()
#      14 return soup
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:193, in ChromiumDriver.quit(self)
#     191     pass
#     192 finally:
# --> 193     self.service.stop()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\service.py:157, in Service.stop(self)
#     155 if self.process is not None and self.process.poll() is None:
#     156     try:
# --> 157         self.send_remote_shutdown_command()
#     158     except TypeError:
#     159         pass
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\service.py:142, in Service.send_remote_shutdown_command(self)
#     139     return
#     141 for _ in range(30):
# --> 142     if not self.is_connectable():
#     143         break
#     144     sleep(1)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\service.py:131, in Service.is_connectable(self)
#     128 def is_connectable(self) -> bool:
#     129     """Establishes a socket connection to determine if the service running
#     130     on the port is accessible."""
# --> 131     return utils.is_connectable(self.port)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\utils.py:101, in is_connectable(port, host)
#      99 socket_ = None
#     100 try:
# --> 101     socket_ = socket.create_connection((host, port), 1)
#     102     result = True
#     103 except _is_connectable_exceptions:
#
# File ~\anaconda3\Lib\socket.py:857, in create_connection(address, timeout, source_address, all_errors)
#     855 except error as exc:
#     856     if not all_errors:
# --> 857         exceptions.clear()  # raise only the last error
#     858     exceptions.append(exc)
#     859     if sock is not None:
#
# KeyboardInterrupt:

# %%
# Adds the grade averages for all students
# most spring sem courses have a url like this: https://karakterer.dtu.dk/Histogram/1/10862/Summer-2024
for i in range(df_length):
    #print(i)
    url = df.loc[i,"Grade_URL"]
    soup = extract_html(url) #Extracts the grade page
    
    #Extracts the grade
    avg_grade = None
    indicator = soup.find('td', string=lambda text: text and "Eksamensgennemsnit" in text) # Finds the indicating label
    if indicator:
        value_cell = indicator.find_next_sibling('td') # finds the position
        avg_grade = value_cell.get_text(strip=True) # defines the string
    df.loc[i,"Average grade"] = avg_grade

    #Extracts the amount of pass students (general not DI)
    passed_students = None
    indicator = soup.find('td', string=lambda text: text and "Antal b" in text) # Finds the indicating label
    if indicator:
        value_cell = indicator.find_next_sibling('td')  # Finds the position
        passed_students = value_cell.get_text(strip=True) if value_cell else None  # Defines the string if value_cell exists
    df.loc[i, "Passed students"] = passed_students  # Assign the result to the dataframe

# %%
df

# %%
# Corrects the course name format
for i in range(df_length):
    df.loc[i,"Course name"] = df.loc[i,"Course name"].strip()[6:].split('(')[0].strip()

# %%
# Corrects the average grade format
for i in range(df_length):
    if df.loc[i,"Average grade"] == None:
        df.loc[i,"Average grade"] = np.nan
    
    elif df.loc[i,"Average grade"].strip()[0].isdigit():
        df.loc[i,"Average grade"] = df.loc[i,"Average grade"].split(' ')[0].replace(",", ".")
    else:
        df.loc[i,"Average grade"] = "Pass/Non-Pass"

# %%
# Corrects Passed students format
for i in range(df_length):
    if df.loc[i, "Passed students"] == None:
        df.loc[i, "Passed students"] = np.nan
    else:
        lines = df.loc[i, "Passed students"].splitlines()
        first_number = next((line.strip() for line in lines if line.strip().isdigit()), None)
        df.loc[i, "Passed students"] = first_number

# %% [markdown]
# ## EVALUATIONS
# ##### Scores
# Average score calculated from a 1-5 score:\
# 1 = Completely disagree \
# 5 = Completely agree
#
# ##### Evaluation questions (translated from Danish)
# 1.1 = I have learned a lot in this course \
# 1.2 = The course activities align well with the learning objectives \
# 1.3 = The course activities motivate me to work with the subject \
# 1.4 = During the course I had the opportunity to get feedback on my academic performance in the course \
# 1.5 = It has been clear to me what has been expected of me from exercises, project work, ect. \
# 2.1 = 5 ECTS is nominated to 9 work hours during a week. I believe that the time I have spent on the course fits that

# %%
# Reading all evaluation files with header=None for raw data loading

# January courses
jan_20 = pd.read_excel("Evaluations/E20-03.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jan_21 = pd.read_excel("Evaluations/E21-03.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jan_22 = pd.read_excel("Evaluations/E22-03.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jan_23 = pd.read_excel("Evaluations/E23-03.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jan_24 = pd.read_excel("Evaluations/E24-03.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)

# June courses
jun_20 = pd.read_excel("Evaluations/F20-03 juni.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jun_21 = pd.read_excel("Evaluations/F21-03 juni.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jun_22 = pd.read_excel("Evaluations/F22-03 juni.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jun_23 = pd.read_excel("Evaluations/F23-03 juni.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
jun_24 = pd.read_excel("Evaluations/F24-03 juni.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)

# July courses
jul_24 = pd.read_excel("Evaluations/F24-03 juli.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)

# August courses
aug_20 = pd.read_excel("Evaluations/F20-03 august.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
aug_21 = pd.read_excel("Evaluations/F21-03 august.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
aug_22 = pd.read_excel("Evaluations/F22-03 august.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
aug_23 = pd.read_excel("Evaluations/F23-03 august.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
aug_24 = pd.read_excel("Evaluations/F24-03 august.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)

# Fall 13-week courses
E20_13W = pd.read_excel("Evaluations/E20-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
E21_13W = pd.read_excel("Evaluations/E21-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
E22_13W = pd.read_excel("Evaluations/E22-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
E23_13W = pd.read_excel("Evaluations/E23-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
E24_13W = pd.read_excel("Evaluations/E24-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)

# Spring 13-week courses
F20_13W = pd.read_excel("Evaluations/F20-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
F21_13W = pd.read_excel("Evaluations/F21-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
F22_13W = pd.read_excel("Evaluations/F22-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
F23_13W = pd.read_excel("Evaluations/F23-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)
F24_13W = pd.read_excel("Evaluations/F24-13.xlsx", sheet_name="Skema A, Kursusevaluering", header=None)

# %%
#Selecting the right columns

#January
jan_20 = jan_20.iloc[1:,[0,9,16,23,30,37,44]]
jan_21 = jan_21.iloc[1:,[0,9,16,23,30,37,44]]
jan_22 = jan_22.iloc[1:,[0,9,16,23,30,37,44]]
jan_23 = jan_23.iloc[1:,[0,9,16,23,30,37,44]]
jan_24 = jan_24.iloc[1:,[0,9,16,23,30,37,44]]

#June
jun_20 = jun_20.iloc[1:,[0,9,16,23,30,37,44]]
jun_21 = jun_21.iloc[1:,[0,9,16,23,30,37,44]]
jun_22 = jun_22.iloc[1:,[0,9,16,23,30,37,44]]
jun_23 = jun_23.iloc[1:,[0,9,16,23,30,37,44]]
jun_24 = jun_24.iloc[1:,[0,9,16,23,30,37,44]]

#July
jul_24 = jul_24.iloc[1:,[0,9,16,23,30,37,44]]

#August
aug_20 = aug_20.iloc[1:,[0,9,16,23,30,37,44]]
aug_21 = aug_21.iloc[1:,[0,9,16,23,30,37,44]]
aug_22 = aug_22.iloc[1:,[0,9,16,23,30,37,44]]
aug_23 = aug_23.iloc[1:,[0,9,16,23,30,37,44]]
aug_24 = aug_24.iloc[1:,[0,9,16,23,30,37,44]]

#Fall 13 week courses
E20_13W = E20_13W.iloc[1:,[0,9,16,23,30,37,44]]
E21_13W = E21_13W.iloc[1:,[0,9,16,23,30,37,44]]
E22_13W = E22_13W.iloc[1:,[0,9,16,23,30,37,44]]
E23_13W = E23_13W.iloc[1:,[0,9,16,23,30,37,44]]
E24_13W = E24_13W.iloc[1:,[0,9,16,23,30,37,44]]

#Spring 13 week courses
F20_13W = F20_13W.iloc[1:,[0,9,16,23,30,37,44]]
F21_13W = F21_13W.iloc[1:,[0,9,16,23,30,37,44]]
F22_13W = F22_13W.iloc[1:,[0,9,16,23,30,37,44]]
F23_13W = F23_13W.iloc[1:,[0,9,16,23,30,37,44]]
F24_13W = F24_13W.iloc[1:,[0,9,16,23,30,37,44]]

# %%
#Assigning correct column labels

#January
jan_20.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jan_21.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jan_22.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jan_23.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jan_24.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]

#June
jun_20.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jun_21.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jun_22.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jun_23.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
jun_24.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]

#July
jul_24.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]

#August
aug_20.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
aug_21.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
aug_22.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
aug_23.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
aug_24.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]

#Fall 13 week courses
E20_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
E21_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
E22_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
E23_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
E24_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]

#Spring 13 week courses
F20_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
F21_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
F22_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
F23_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]
F24_13W.columns = ["Course code", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]

# %%
# Assigning semester code

#January courses
jan_20["Semester"] = "E20"
jan_21["Semester"] = "E21"
jan_22["Semester"] = "E22"
jan_23["Semester"] = "E23"
jan_24["Semester"] = "E24"

#June courses
jun_20["Semester"] = "F20"
jun_21["Semester"] = "F21"
jun_22["Semester"] = "F22"
jun_23["Semester"] = "F23"
jun_24["Semester"] = "F24"

#July courses
jul_24["Semester"] = "F24"

#August courses
aug_20["Semester"] = "F20"
aug_21["Semester"] = "F21"
aug_22["Semester"] = "F22"
aug_23["Semester"] = "F23"
aug_24["Semester"] = "F24"

#Fall 13 week courses
E20_13W["Semester"] = "E20"
E21_13W["Semester"] = "E21"
E22_13W["Semester"] = "E22"
E23_13W["Semester"] = "E23"
E24_13W["Semester"] = "E24"

#Spring 13 week courses
F20_13W["Semester"] = "F20"
F21_13W["Semester"] = "F21"
F22_13W["Semester"] = "F22"
F23_13W["Semester"] = "F23"
F24_13W["Semester"] = "F24"

# %%
# Assigning Placement code

#January courses
jan_20["Placement"] = "January"
jan_21["Placement"] = "January"
jan_22["Placement"] = "January"
jan_23["Placement"] = "January"
jan_24["Placement"] = "January"

#June courses
jun_20["Placement"] = "June"
jun_21["Placement"] = "June"
jun_22["Placement"] = "June"
jun_23["Placement"] = "June"
jun_24["Placement"] = "June"

#July courses
jul_24["Placement"] = "July"

#August courses
aug_20["Placement"] = "August"
aug_21["Placement"] = "August"
aug_22["Placement"] = "August"
aug_23["Placement"] = "August"
aug_24["Placement"] = "August"

#Fall 13 week courses
E20_13W["Placement"] = "Fall"
E21_13W["Placement"] = "Fall"
E22_13W["Placement"] = "Fall"
E23_13W["Placement"] = "Fall"
E24_13W["Placement"] = "Fall"

#Spring 13 week courses
F20_13W["Placement"] = "Spring"
F21_13W["Placement"] = "Spring"
F22_13W["Placement"] = "Spring"
F23_13W["Placement"] = "Spring"
F24_13W["Placement"] = "Spring"

# %%
#Creating the whole evaluation df
evals = [jan_20, jan_21, jan_22, jan_23, jan_24,
        jun_20, jun_21, jun_22, jun_23, jun_24,
        jul_24,
        E20_13W, E21_13W, E22_13W, E23_13W, E24_13W, 
        F20_13W, F21_13W, F22_13W, F23_13W, F24_13W]

eval = pd.concat(evals, ignore_index=True)

# %%
#Creating new columns
df[["Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1", "Placement"]] = ""

# %%
#Normalizing the matching features
df["Course code"] = df["Course code"].astype(str).str.strip()
df["Semester"] = df["Semester"].astype(str).str.strip()
eval["Course code"] = eval["Course code"].astype(str).str.strip()
eval["Semester"] = eval["Semester"].astype(str).str.strip()

# %%
# Assigning evaluation values to df
for i in range(df_length):
    if i == 0 or i == 1:
        df.loc[i,"Placement"] = np.nan
        df.loc[i,"Eval_1.1"] = np.nan
        df.loc[i,"Eval_1.2"] = np.nan
        df.loc[i,"Eval_1.3"] = np.nan
        df.loc[i,"Eval_1.4"] = np.nan
        df.loc[i,"Eval_1.5"] = np.nan
        df.loc[i,"Eval_2.1"] = np.nan
        
    else:
        for j in range(len(eval)):
            if df.loc[i,"Course code"] == eval.loc[j,"Course code"] and df.loc[i, "Semester"] == eval.loc[j,"Semester"]:
                
                df.loc[i,"Eval_1.1"] = eval.loc[j,"Eval_1.1"]
                df.loc[i,"Eval_1.2"] = eval.loc[j,"Eval_1.2"]
                df.loc[i,"Eval_1.3"] = eval.loc[j,"Eval_1.3"]
                df.loc[i,"Eval_1.4"] = eval.loc[j,"Eval_1.4"]
                df.loc[i,"Eval_1.5"] = eval.loc[j,"Eval_1.5"]
                df.loc[i,"Eval_2.1"] = eval.loc[j,"Eval_2.1"]
                df.loc[i, "Placement"] = eval.loc[j,"Placement"]

# %% [markdown]
# ## CLEAN UP & EXPORT

# %%
# Dropping columns that are only neccesary for the data load
filter = ["Term", "School year", "URL", "Grade_URL"]
df = df.drop(columns=filter)

# %%
#Rename semester values
df["Semester"] = df["Semester"].apply(lambda x: f"Spring 20{x[1:]}" if isinstance(x, str) and x.startswith("F") else x)
df["Semester"] = df["Semester"].apply(lambda x: f"Fall 20{x[1:]}" if isinstance(x, str) and x.startswith("E") else x)

# %%
# Reorder columns
df = df[["Course code", "Course name", "Semester", "Level", "ECTS", "Course type", "Passed DI students", "Passed students", "Average grade", "Placement", "Year_URL", "Eval_1.1", "Eval_1.2", "Eval_1.3", "Eval_1.4", "Eval_1.5", "Eval_2.1"]]

# %%
#Save data
df.to_excel("DataFrame.xlsx", index=False)

# %%
df
